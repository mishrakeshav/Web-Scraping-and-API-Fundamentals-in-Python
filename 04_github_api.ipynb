# %%
import requests
import json

# %%
base_site = "https://jobs.github.com/positions.json"

# %%
r = requests.get(base_site , params = {'description': 'data science', 'location': 'los angeles'})

# %%
r.status_code
# Out:
# 200

# %%
r.json()
# Out:
# [{'id': 'd5955556-de1b-11e8-97e2-45ff61609ad8',
#   'type': 'Full Time',
#   'url': 'https://jobs.github.com/positions/d5955556-de1b-11e8-97e2-45ff61609ad8',
#   'created_at': 'Thu Nov 01 21:20:36 UTC 2018',
#   'company': 'PlayVS',
#   'company_url': 'http://www.playvs.com',
#   'location': 'Santa Monica, CA',
#   'title': 'Software Engineer, Full Stack',
#   'description': '<p>PlayVS is building the infrastructure and official platform for high school esports. We work with game publishers and high school governing bodies to build and operate sanctioned leagues across the country. Our software products tie everything together, creating the world’s first full-stack sports platform. PlayVS is headquartered in Santa Monica, CA and rapidly expanding.</p>\n<p>As an engineer, you’ll be expected to do the normal tech startup duties including:</p>\n<ul>\n<li>\n<p>Writing clean, easily-maintainable code. We’re extremely proud of our lack of technical debt and want to keep it that way.</p>\n</li>\n<li>\n<p>Debugging, documentation, and unit testing. Everyone loves a smooth game day.</p>\n</li>\n<li>\n<p>Have a natural knack for user experience and pixel-perfect design. You should know CSS like it’s the back of your hand, and be extremely comfortable building modern responsive web apps.</p>\n</li>\n<li>\n<p>Being flexible about your day-to-day tasks. We do everything from tweaking marketing pages to building the real-time match-play systems and data pipelines. You will wear many hats here.</p>\n</li>\n<li>\n<p>Improving our internal tooling and engineering process by contributing your knowledge and unique background.</p>\n</li>\n</ul>\n<p>What we’re looking for:</p>\n<ul>\n<li>\n<p>4+ years of technical experience</p>\n</li>\n<li>\n<p>Interest in gaming or esports, though no prior experience is required\nExperience using NodeJS or NoSQL data stores like Redis, RethinkDB or Mongo</p>\n</li>\n<li>\n<p>Expert developing interfaces using ReactJS</p>\n</li>\n<li>\n<p>Top-notch CSS skills</p>\n</li>\n<li>\n<p>Comfortable working with WebSockets</p>\n</li>\n<li>\n<p>Degree in Computer Science preferred</p>\n</li>\n</ul>\n<p>At PlayVS, we put a heavy emphasis on inclusiveness, diversity, and most importantly, player experience. Our team is small, scrappy, and incredibly talented. The challenges we solve on a daily basis are exciting and relevant. This role is $110K+.  If you are driven by seeing the immediate impact that your code brings, you’ll fit right in here.</p>\n',
#   'how_to_apply': '<p>Email us at <a href="mailto:careers@playvs.com">careers@playvs.com</a></p>\n',
#   'company_logo': 'https://jobs.github.com/rails/active_storage/blobs/eyJfcmFpbHMiOnsibWVzc2FnZSI6IkJBaHBBa2xXIiwiZXhwIjpudWxsLCJwdXIiOiJibG9iX2lkIn19--02900ed15126cfa0983ebd48ddba2b07539f4c62/7f3abee5-837b-49da-93f7-b44fbe23fc0a'},
#  {'id': 'c65408fa-de19-11e8-844c-e31925c0b958',
#   'type': 'Full Time',
#   'url': 'https://jobs.github.com/positions/c65408fa-de19-11e8-844c-e31925c0b958',
#   'created_at': 'Thu Nov 01 21:06:30 UTC 2018',
#   'company': 'PlayVS',
#   'company_url': 'http://www.playvs.com',
#   'location': 'Santa Monica, CA',
#   'title': 'Software Engineer, Frontend ',
#   'description': '<p>PlayVS is building the infrastructure and official platform for high school esports. We work with game publishers and high school governing bodies to build and operate sanctioned leagues across the country. Our software products tie everything together, creating the world’s first full-stack sports platform. PlayVS is headquartered in Santa Monica, CA and rapidly expanding.</p>\n<p>As an engineer, you’ll be expected to do the normal tech startup duties including:</p>\n<ul>\n<li>\n<p>Writing clean, easily-maintainable code. We’re extremely proud of our lack of technical debt and want to keep it that way.</p>\n</li>\n<li>\n<p>Debugging, documentation, and unit testing. Everyone loves a smooth game day.</p>\n</li>\n<li>\n<p>Have a natural knack for user experience and pixel-perfect design. You should know CSS like it’s the back of your hand, and be extremely comfortable building modern responsive web apps.</p>\n</li>\n<li>\n<p>Being flexible about your day-to-day tasks. We do everything from tweaking marketing pages to building the real-time match-play systems and data pipelines. You will wear many hats here.</p>\n</li>\n<li>\n<p>Improving our internal tooling and engineering process by contributing your knowledge and unique background.</p>\n</li>\n</ul>\n<p>What we’re looking for:</p>\n<ul>\n<li>\n<p>4+ years of technical experience</p>\n</li>\n<li>\n<p>Interest in gaming or esports</p>\n</li>\n<li>\n<p>Expert developing interfaces using ReactJS</p>\n</li>\n<li>\n<p>Top-notch CSS skills</p>\n</li>\n<li>\n<p>Comfortable working with WebSockets</p>\n</li>\n<li>\n<p>Degree in Computer Science preferred</p>\n</li>\n</ul>\n<p>At PlayVS, we put a heavy emphasis on inclusiveness, diversity, and most importantly, player experience. Our team is small, scrappy, and incredibly talented. The challenges we solve on a daily basis are exciting and relevant.  This role is $90k+.  If you are driven by seeing the immediate impact that your code brings, you’ll fit right in here.\n</p>\n',
#   'how_to_apply': '<p>Email us at <a href="mailto:careers@playvs.com">careers@playvs.com</a></p>\n',
#   'company_logo': 'https://jobs.github.com/rails/active_storage/blobs/eyJfcmFpbHMiOnsibWVzc2FnZSI6IkJBaHBBa2RXIiwiZXhwIjpudWxsLCJwdXIiOiJibG9iX2lkIn19--c006ca2e3659381100d6f6de12d331553cce4e33/2f5dd3f9-319e-4b5e-ab32-093701b04d06'},
#  {'id': '1ef41916-dd5f-11e8-98aa-d336cb7192b8',
#   'type': 'Full Time',
#   'url': 'https://jobs.github.com/positions/1ef41916-dd5f-11e8-98aa-d336cb7192b8',
#   'created_at': 'Wed Oct 31 22:54:08 UTC 2018',
#   'company': 'playvs-inc',
#   'company_url': None,
#   'location': 'Santa Monica, CA',
#   'title': 'Software Engineer, Backend',
#   'description': '<p>PlayVS is building the infrastructure and official platform for high school esports. We work with game publishers and high school governing bodies to build and operate sanctioned leagues across the country. Our software products tie everything together, creating the world’s first full-stack sports platform. PlayVS is headquartered in Santa Monica, CA and rapidly expanding.</p>\n<p>As an engineer, you’ll be expected to do the normal tech startup duties including:</p>\n<ul>\n<li>\n<p>Writing clean, easily-maintainable code. We’re extremely proud of our lack of technical debt and want to keep it that way.</p>\n</li>\n<li>\n<p>Debugging, documentation, and unit testing. Everyone loves a smooth game day.</p>\n</li>\n<li>\n<p>Building and integrating APIs</p>\n</li>\n<li>\n<p>Being flexible about your day-to-day tasks. We do everything from tweaking marketing pages to building the real-time match-play systems and data pipelines.</p>\n</li>\n<li>\n<p>Improving our internal tooling and engineering process by contributing your knowledge and unique background.</p>\n</li>\n</ul>\n<p>What we’re looking for:</p>\n<ul>\n<li>\n<p>4+ years of technical experience</p>\n</li>\n<li>\n<p>Interest in gaming or esports</p>\n</li>\n<li>\n<p>Experience using NodeJS or NoSQL data stores like Redis, RethinkDB or Mongo</p>\n</li>\n<li>\n<p>Comfortable working with WebSockets</p>\n</li>\n<li>\n<p>Degree in Computer Science preferred</p>\n</li>\n</ul>\n<p>At PlayVS, we put a heavy emphasis on inclusiveness, diversity, and most importantly, player experience. Our team is small, scrappy, and incredibly talented. The challenges we solve on a daily basis are exciting and relevant. This role is 90k and up. If you are driven by seeing the immediate impact that your code brings, you’ll fit right in here.</p>\n',
#   'how_to_apply': '<p>Please email us at <a href="mailto:careers@playvs.com">careers@playvs.com</a></p>\n',
#   'company_logo': 'https://jobs.github.com/rails/active_storage/blobs/eyJfcmFpbHMiOnsibWVzc2FnZSI6IkJBaHBBaXBXIiwiZXhwIjpudWxsLCJwdXIiOiJibG9iX2lkIn19--13c421e8ce9526b4489d8262c8e069636a4a6285/967eb69a-ee1a-490c-b2cc-8ea54070fc36'}]

# %%
r = requests.get(base_site)

# %%
r
# Out:
# <Response [200]>

# %%
r.json()
# Out:
# [{'id': '46d4783d-6032-4e47-a485-336b2c6d2a35',
#   'type': 'Contract',
#   'url': 'https://jobs.github.com/positions/46d4783d-6032-4e47-a485-336b2c6d2a35',
#   'created_at': 'Sat Apr 11 16:30:39 UTC 2020',
#   'company': 'Signature Creative Inc.',
#   'company_url': None,
#   'location': 'Los Angeles',
#   'title': 'Wordpress Developer',
#   'description': "<p><strong>Who We Are</strong></p>\n<p>Established in 2004, Signature Creative is a full-service agency helping startups, rising companies and Fortune 500 businesses successfully launch products from concept to commercialization. For 14 years, Signature Creative has been an innovation leader in the product and digital development landscapes working with a diverse mix of global clients.</p>\n<p><strong>The Role</strong></p>\n<p>Signature Creative is looking for an experienced Web Developer to work across its expanding portfolio of clients. The ideal candidate will have solid back-end and front-end development experience, as well as skilled in responsive design. You will work across a variety of clients within entertainment, music, technology and more. This role requires a seasoned leader, someone who can drive multiple projects and manage staff. You are a proven self-starter with\nability to work independently in a fast-paced environment. You are an innovative thinker, providing new ideas and consistently offering innovative solutions.</p>\n<p><strong>Core Duties/Responsibilities</strong></p>\n<ul>\n<li>Leading WordPress projects, from scoping and strategy all the way through building and supporting, large and complex WordPress sites.</li>\n<li>Expert in Plugin Development</li>\n<li>Extensive experience and knowledge in running Wordpress as Docker Container</li>\n<li>Expert in performance optimization (caching, etc.)</li>\n<li>Experience and knowledge of security related aspects</li>\n<li>Experience in Authorization and Authentication – (eg- OAUTH2)</li>\n<li>Deep experience in Wordpress APIs and headless design experience is preferred</li>\n<li>Collaborating with design and front-end engineering teams to ensure effectiveness and quality</li>\n<li>Taking part in our code review process (both reviewing the work of other developers and having your own work reviewed)</li>\n<li>Working with project managers to come up with creative and effective solutions to our client's problems</li>\n</ul>\n<p><strong>What We're looking for</strong></p>\n<ul>\n<li>Extensive hands on experience in CMS development, with a strong focus on WordPress</li>\n<li>Hands on experience with Wordpress, CSS, Javascript, HTML5 and PHP</li>\n<li>Experience building and maintaining custom WordPress Plugins</li>\n<li>A working knowledge of git</li>\n<li>Building websites using WordPress and other open source software</li>\n<li>Being an expert problem solver and technical innovator, and an ability to identify, understand, and implement viable new technologies.</li>\n<li>Excellent communication skills</li>\n<li>server-side JS development, like node.js</li>\n<li>Have experience with object oriented programming</li>\n<li>Have experience with agile workflows</li>\n<li>Have experience with automated testing</li>\n<li>Convert UI/UX designs and mocks to functional, custom themes in Wordpress</li>\n<li>Excellent troubleshooting skills - CSS, Layouts, graphics etc. - cross browser compatible</li>\n</ul>\n",
#   'how_to_apply': '<p>APPLY HERE\n<a href="https://forms.gle/mKk69CVfnkQ4cQFu7">https://forms.gle/mKk69CVfnkQ4cQFu7</a></p>\n',
#   'company_logo': 'https://jobs.github.com/rails/active_storage/blobs/eyJfcmFpbHMiOnsibWVzc2FnZSI6IkJBaHBBdDZCIiwiZXhwIjpudWxsLCJwdXIiOiJibG9iX2lkIn19--627dc92753170ca2203e78e24b11422d573bbef1/blue-690x550.jpg'},
#  {'id': '31e45250-1575-4e94-ab3e-1eef6a53990d',
#   'type': 'Full Time',
#   'url': 'https://jobs.github.com/positions/31e45250-1575-4e94-ab3e-1eef6a53990d',
#   'created_at': 'Sat Apr 11 07:35:22 UTC 2020',
#   'company': 'FlatWorld.co',
#   'company_url': 'http:',
#   'location': 'Remote: GMT+3 to GMT-5',
#   'title': '[REMOTE] Sr. Fullstack React + Node',
#   'description': '<p>This is an exciting opportunity for an experienced Sr. full-stack developer with a true passion for technology to join a successful growing fin-tech company backed by some of the best investors out there and a fully distributed team spread across the EU. You’ll be working from home (or 𝗮𝗻𝘆𝘄𝗵𝗲𝗿𝗲 🌍) free from the daily 🚗🚗🚗 and the limited number of local opportunities, earning $60K to $96K/year + equity based on experience and fit.</p>\n<p>The company’s platform streamlines all compliance and payments for companies working as fully distributed teams empowering the future of work.</p>\n<p>Culture is critical to us, and we are transparent about our vision and principles. We have an exciting product roadmap in areas like Fintech infrastructure and workflow automation.</p>\n<p>Do you have software engineering expertise, a dedicated business-driven approach to problem-solving, self-direction, and a strong belief that the team can achieve more than each of its members individually? Our current technology stack is node.js on the backend and React on the frontend – we are fully serverless and use PostgreSQL for storing data.</p>\n<p>Read more details in the "How To Apply Link"</p>\n',
#   'how_to_apply': '<p>Full job description &amp; link to apply: <a href="https://tny.sh/V69MPPk">https://tny.sh/V69MPPk</a></p>\n',
#   'company_logo': 'https://jobs.github.com/rails/active_storage/blobs/eyJfcmFpbHMiOnsibWVzc2FnZSI6IkJBaHBBdG1CIiwiZXhwIjpudWxsLCJwdXIiOiJibG9iX2lkIn19--b85b7b710663d42754f478f8b3b06eecd58ff79e/logo-flatworld-cropped.png'},
#  {'id': '90cc0d62-ebfa-482a-a195-59afeb958000',
#   'type': 'Full Time',
#   'url': 'https://jobs.github.com/positions/90cc0d62-ebfa-482a-a195-59afeb958000',
#   'created_at': 'Fri Apr 10 18:33:36 UTC 2020',
#   'company': 'Clockwork Trading',
#   'company_url': 'https://thehub.io/startups/clockwork-trading',
#   'location': 'Copenhagen',
#   'title': 'Tech Lead',
#   'description': "<p>Clockwork is a startup revolutionizing the investment experience by offering a user-centered platform with innovative user interface and user experience. We’re not like any existing financial solution. On our app users can invest into a broad universe including the most exciting tech stocks and leading cryptocurrencies on a gamified platform that simplifies insight and decision-making. We’re all about making investing easily accessible to the many and not only to the few.</p>\n<p>NB, we're about to change our name, identity, website, etc. as part of a rebranding process.</p>\n<p>Opportunity</p>\n<p>Do you want to rethink and build the innovative millennial investment platform? Would you like to make a big difference for a lot of people? As our Tech Lead, you’ll be forward-looking in conceptualizing and implementing new secure systems for our innovative investment application. You’ll work with a wide focus on optimizing agile development processes. You and the dev team will take the technical responsibility for a highly efficient and secure investment platform.</p>\n<p>Profile</p>\n<ul>\n<li>Desirably a degree in Computer Science, Engineering, Mathematics or equivalent, but not required.</li>\n<li>Sound fundamentals in problem-solving, algorithm design and system design.</li>\n<li>Experience with cloud computing (AWS).</li>\n<li>Languages/Syntax: Experience in either C# or Python, and SQL. Understanding of Node.js, React Native, and Typescript is desirable.</li>\n<li>Familiar with Git or CodeCommit for version control.</li>\n<li>Preferably knowledge of working with big data financial systems, but not required.</li>\n</ul>\n<p>The Role</p>\n<p>Imagine creating the absolutely best investment experience. Bring passion and dedication to your work and there's no limitation to what you could accomplish. We’re looking for a Tech Lead who can lead and collaborate with backend-, blockchain-, and frontend engineers as well as data scientists on performance, functionality, and automation to enhance the user experience.</p>\n<p>This role requires you as a candidate to own the quality of the code you write, with tests that keep the codebase in check to ensure the platform is rock solid. You’ll contribute to the long-term engineering excellence of the Clockwork systems including designing, implementing and reviewing new APIs. We look for someone who is driven to solve problems with new ideas and take action to bring them to life.</p>\n<p>Team</p>\n<p>As a team, we value people, fun, disruption, transparency, intuitiveness, and excellence. People are important to us, which means social activities both with the team itself and together with the users. We’re building a creative environment with the freedom to innovate. Ambition is a must as we’re enjoying disrupting a legacy industry.</p>\n<p>Our stack</p>\n<p>Server Architecture: Lambda, EC2, Elastic Beanstalk.\nAPI Service: Rest and Websocket through API Gateway.\nMicroservices: AWS Microservices.\nRelational Database: AWS RDS, Aurora, MySQL.</p>\n<p>Formalities</p>\n<p>Our office is at the Symbion co-working space in Østerbro, Copenhagen, Denmark, which means you’ll be working in a vibrant and highly creative atmosphere.</p>\n<p>The Tech Lead role comes with the opportunity of gaining equity. We offer flexible working hours and the opportunity to work from home as well as free coffee, tea, office snacks, and gym access.</p>\n<p>If you have any questions regarding the position, please contact Rasmus Koch Nielsen by mail.</p>\n<p>Clockwork is an equal opportunity employer. We offer employment opportunities to members of all backgrounds, perspectives, and abilities. We’re counting six employees and six different nationalities.</p>\n",
#   'how_to_apply': '<p>Email <a href="mailto:rkn@clockworktrader.com">rkn@clockworktrader.com</a></p>\n<p>Or apply here <a href="https://thehub.io/jobs/5e8779fe47fffe42bec7ad5f">https://thehub.io/jobs/5e8779fe47fffe42bec7ad5f</a></p>\n',
#   'company_logo': 'https://jobs.github.com/rails/active_storage/blobs/eyJfcmFpbHMiOnsibWVzc2FnZSI6IkJBaHBBdFNCIiwiZXhwIjpudWxsLCJwdXIiOiJibG9iX2lkIn19--6919a58d69127f4c5519a46592d004b8d6a2cb6b/Clockwork-logo-rgb-squared.jpg'},
#  {'id': 'a693d488-1510-4b2d-b6f7-4c820aad1ef7',
#   'type': 'Full Time',
#   'url': 'https://jobs.github.com/positions/a693d488-1510-4b2d-b6f7-4c820aad1ef7',
#   'created_at': 'Fri Apr 10 16:38:59 UTC 2020',
#   'company': 'StreamLocator',
#   'company_url': 'https://www.streamlocator.com/',
#   'location': 'Remote / Work from home',
#   'title': 'Experience Android Developer',
#   'description': "<p><strong>About StreamLocator</strong></p>\n<p>We started our company with the belief that the internet should be free of geographic borders that restrict access to the content people want to watch. We solve this problem with technology that is delivered through easy-to-use tools.</p>\n<p>We are a small, experienced team who enjoy working with each other. Conversations are often about exploration and the exchange of ideas. Joining our team means valuing and being part of these conversations. This is a startup and successful team members are independent, resourceful and creative, who thrive in a more unstructured environment with little hand holding. We measure results instead of effort, we value the ability to have a flexible schedule and be in control of your own time.</p>\n<p><strong>The Role</strong></p>\n<p>We are looking for an Experienced Android Developer to release and maintain our Android app, and improve our Amazon FireTV app. This is a fully or partially remote position.</p>\n<p><strong>Goals</strong></p>\n<ul>\n<li>Support the product team in A/B testing of the apps</li>\n<li>Release updated versions of the apps on biweekly sprints fixing issues reported by customers</li>\n<li>Take partially completed and unpublished Android app and launch on Google Play store within a month</li>\n<li>Work with support department to identify and fix issues within 48 hours</li>\n</ul>\n<p><strong>How You Will Achieve These Goals</strong></p>\n<ul>\n<li>Be fully responsible for the FireTV and Android apps</li>\n<li>Improve and maintain the FireTV app</li>\n<li>Clean up existing app code</li>\n<li>Work with product team to enhance or modify features and functionality of Android and FireTV apps</li>\n</ul>\n<p><strong>Our Tech Stack</strong></p>\n<ul>\n<li>JSON based backend API</li>\n<li>Android + Javascript frontend for FireTV</li>\n<li>Android + native UI for Google Play</li>\n<li>VPN Service based implementation</li>\n</ul>\n<p><strong>Must Have</strong></p>\n<ul>\n<li>5+ years of experience building Android applications</li>\n<li>Solid understanding of the various Android SDK's, supporting multiple versions of Android OS in a single app</li>\n<li>Experience using REST and JSON based APIs</li>\n<li>A solid understanding of UI/UX design, experience working with HTML and JavaScript based front end</li>\n<li>Knowledge of the Google Play store marketplace, including app packaging, signing and in app purchasing management</li>\n<li>Experience with TCP/IP networking, including VPNs, Tunneling and DNS</li>\n<li>Self managed, experience working remotely</li>\n</ul>\n",
#   'how_to_apply': '<p>Follow the link to apply: <a href="https://streamlocator.applytojob.com/apply/qLYwK9NWM4/Experienced-Android-Developer">https://streamlocator.applytojob.com/apply/qLYwK9NWM4/Experienced-Android-Developer</a></p>\n',
#   'company_logo': 'https://jobs.github.com/rails/active_storage/blobs/eyJfcmFpbHMiOnsibWVzc2FnZSI6IkJBaHBBdENCIiwiZXhwIjpudWxsLCJwdXIiOiJibG9iX2lkIn19--853c21e38feceb36f710437dca936d54fbc1cfe3/logo.png'},
#  {'id': '631d654c-0782-4d9c-b454-512725069274',
#   'type': 'Full Time',
#   'url': 'https://jobs.github.com/positions/631d654c-0782-4d9c-b454-512725069274',
#   'created_at': 'Fri Apr 10 12:33:53 UTC 2020',
#   'company': 'Politie',
#   'company_url': 'http:',
#   'location': 'Driebergen-Rijsenburg',
#   'title': 'platform engineer',
#   'description': '<p>Als platform engineer bij het Warehouseteam wordt veel van jouw technische skills gevraagd bij het bouwen en beheren van een cloud-platform. Ben jij een netwerker en in staat om samen met de politieoperatie kansen om te zetten naar technische oplossingen? Dan zoeken wij jou!</p>\n<p><strong>Wat ga je doen?</strong></p>\n<p>Als platform engineer bouw je samen met andere cloud engineers het cloud-platform. Vervolgens beheer je dit platform en zorg je voor de uitbreidingen. Het cloud platform vereist voor het dagelijks beheer niet veel tijd en moeite. De nadruk ligt dan ook op het uitbouwen van de functionaliteit. Denk hierbij aan het uitbreiden van de diensten (tegels) die het platform beschikbaar stelt.</p>\n<p>Als jij je werk goed doet, doe je hooguit één keer iets handmatig. Als het vaker moet, dan automatiseer je het. Je zorgt ervoor dat het platform veilig is en blijft, terwijl de gebruikers er goed en flexibel gebruik van kunnen maken. Dat doe je door er voor te zorgen dat er (op tijd) gepatched kan worden zonder downtime. Gebruikers van het platform die vragen hebben probeer je altijd verder te helpen. Dit doe je zo efficiënt mogelijk, zodat je tijd overhoudt voor het uitbreiden van de diensten op het platform en daarmee de beschikbare functionaliteit.</p>\n<p><strong>Waar ga je werken?</strong></p>\n<p>Het Team High Tech Crime van de Dienst Landelijke Recherche kan op eigen initiatief opsporingsonderzoeken starten op basis van gesignaleerde trends en analyses. \'Aan de voorkant komen\' is een belangrijk wapen; wat zijn nieuwe programma\'s, devices en methodes waarmee we cybercriminelen voor kunnen zijn? Via internationale rechtshulpverzoeken wordt de grensoverschrijdende cybercrime aangepakt. En bij zaken die regionale politie-eenheden overstijgen, adviseert ons team de collega\'s in de eenheid met kennis en nieuwe digitale technieken.</p>\n<p>Je komt te werken bij het Warehouseteam, dat ten dienste staat van alle cyberteams van de politie. Het Warehouse is het hart van ons werkproces. In het Warehouse verzamelen wij onze data en wordt deze door middel van een extract transform load tool beschikbaar gemaakt voor diverse tooling. De extracties, verrijkingen en tools die je ontwikkelt staan alle ten dienste van de opsporing. Daarbij werk je samen met developers, digitaal rechercheurs, data engineers en data scientists. Ook zal je betrokken worden bij de grotere onderzoeken waar er veel data beschikbaar komt. Het team werkt vanuit Driebergen. Het pand ligt direct aan de A12 en is uitstekend bereikbaar.</p>\n<p><strong>Wie ben jij?</strong></p>\n<p>Er wordt veel verwacht van je technische skills. Je hebt ervaring met meerdere besturingssystemen, databases en internet- en netwerktechnologieën. Met je brede IT-kennis ben je in staat om productieproblemen op te lossen. Hierbij blijf je op de hoogte van alle ontwikkelingen en trends. Je bent een netwerker en vanuit je netwerk ben je in staat om samen met andere eenheden en diensten kansen om te zetten naar technische oplossingen. Je bent analytisch zeer sterk en beschikt over een logisch denkvermogen.</p>\n<p>Verder heb je :</p>\n<ul>\n<li>een hbo-diploma op IT-gebied;</li>\n<li>ervaring met:</li>\n<li>de automatisering van infrastructuur en deployments;</li>\n<li>continuous integration met tooling als Jenkins en Concourse;</li>\n<li>VMware, VSphere en ESXI/ESX;</li>\n<li>netwerktechnologieën als Load balancing, IP, DNS, SSL, firewalls en routeringen;</li>\n<li>GIT;</li>\n<li>Python.</li>\n<li>bij voorkeur ook ervaring met:</li>\n<li>OpenStack, AWS, Azure of Google Cloud Experience;</li>\n<li>Chef, Puppet, BOSH of soortelijke tooling;</li>\n<li>authentiseren met SAML/oAuth2/AD;</li>\n<li>database servers (MySQL, PostgreSQL enzovoort.);</li>\n<li>messaging middleware zoals RabbitMQ;</li>\n<li>systeem monitoring en analyse tooling.</li>\n</ul>\n<p><strong>Wat wij bieden</strong></p>\n<p>De standplaats is Driebergen. Er is ruimte voor 1 fte. Het betreft een fun ...
#   'how_to_apply': '<p>Klik hier om te solliciteren!: <a href="https://vonq.io/3c8SIDs">https://vonq.io/3c8SIDs</a></p>\n',
#   'company_logo': 'https://jobs.github.com/rails/active_storage/blobs/eyJfcmFpbHMiOnsibWVzc2FnZSI6IkJBaHBBc3FCIiwiZXhwIjpudWxsLCJwdXIiOiJibG9iX2lkIn19--ff156aabcb3223623c0b4aef467a42f7a9c908aa/Politie%20logo.jpg'},
#  {'id': 'de607414-e8d3-4b0a-9b32-35cb35b9f80a',
#   'type': 'Full Time',
#   'url': 'https://jobs.github.com/positions/de607414-e8d3-4b0a-9b32-35cb35b9f80a',
#   'created_at': 'Fri Apr 10 10:23:43 UTC 2020',
#   'company': 'de Volksbank',
#   'company_url': 'https://www.devolksbank.nl/home.html',
#   'location': "'s Hertogenbosch",
#   'title': 'Java developer digitale klantomgeving',
#   'description': '<p>De maatregelen rondom COVID-19 hebben helaas ook impact op onze sollicitatieprocedure. Meer informatie vind je <a href="https://werkenbij.devolksbank.nl/verhalen/covid-19-en-solliciteren-bij-de-volksbank-antwoorden-op-jouw-vragen/">hier</a> of neem bij vragen contact op met de recruiter.</p>\n<h2><strong>Zo ziet jouw baan eruit</strong></h2>\n<h2><strong>Werk jij mee aan webapplicaties voor instant payments, waardoor een overgemaakt bedrag altijd binnen enkele seconden op je rekening staat? Of een app waarmee je je rekeningoverzichten van verschillende banken in één oogopslag kunt inzien?</strong></h2>\n<p>Als Java-developer bij de Volksbank duik jij in een wereld die de financiële dienstverlening voor miljoenen klanten versnelt, verbetert en vereenvoudigt. Dankzij jou hebben we een wendbaar applicatielandschap dat aan de backend op-en-top functioneert.</p>\n<p>Bij de Volksbank ontwikkelen we een groot deel van onze responsive webapplicaties zelf. Jij speelt hierin een belangrijke rol. Als Java-developer ontwerp, bouw, test, beheer en documenteer je API’s die er achter de schermen voor zorgen dat verschillende applicaties met elkaar kunnen communiceren. Hiervoor gebruik je onder meer innovatieve backend-technieken, microservices, container- en cloudtechnologieën en opensourcesoftware.</p>\n<p>In een multidisciplinair scrumteam werk je aan één product, namelijk de Mijn Omgeving. Deze Mijn omgeving is de digitale klantomgeving voor klanten van SNS, ASN Bank, Regiobank en BLG Wonen. Denk hierbij onder andere aan inzage in producten die klanten hebben, het uitvoeren van transacties maar ook het kunnen beheren van digitale spaarpotten. Aan de Mijn Omgeving werken diverse scrumteams met behulp van de nieuwste technieken (angular 8, Microservices architectuur (API’s) tooling (CI/CD) en processen (Scrum / DEVOPS). Als onderdeel van het scrumteam bepaal jij samen met je team hoe de MIJN omgeving opgezet wordt.</p>\n<h2><strong>Over het team</strong></h2>\n<p>Jij gaat werken bij een van de scrumteams van de value-organisatie. Jouw team ontwikkelt applicaties die nodig zijn om veranderingen in de business te realiseren en implementeren op het gebied van betalen, wonen, finance en risk, en klantrelaties. Ook zelf zijn we volop in ontwikkeling. Zo beland je midden in de transitie naar DevOps-teams en krijg je de kans om mee te denken over verbetering en verandering. Hoewel je standplaats Den Bosch is, kan het zijn dat je ook regelmatig thuis of op onze locatie in Utrecht werkt.</p>\n<h2><strong>Jouw kwaliteiten</strong></h2>\n<p>Een ervaren professional met een flinke dosis lef en een aanstekelijke teamspirit. Dat ben jij in een notendop. Daarnaast beschik je over een kritische blik, het vermogen om complexe problemen te analyseren en de vindingrijkheid om eenvoudige creatieve oplossingen te bedenken. Nieuwe technologische ontwikkelingen volg je op de voet, bijvoorbeeld doordat je onze lezingen, pizzasessies en hackathons bijwoont. Natuurlijk deel je de kennis die je opdoet vervolgens graag met je peers.</p>\n<p>Verder heb je:</p>\n<ul>\n<li>HBO/WO niveau, bij voorkeur een diploma in de richting van software-engineering of computerscience;</li>\n<li>Meerdere jaren ervaring met backend-ontwikkeling (minimaal 3 jaar ervaring);</li>\n<li>Ervaring met Java-frameworks, zoals Spring Framework, Spring Boot, Spring REST, JAX-RS, JAXB, JPA, JUnit en Mockito;</li>\n<li>Kennis van onder meer IntelliJ of Eclipse, Maven, SQL Databases, Docker of Kubernetes en Git.</li>\n</ul>\n<h2><strong>Solliciteren?</strong></h2>\n<p>Upload je motivatie en cv via <a href="https://vonq.io/3efdRxY">deze link</a>. We nemen dan zo snel mogelijk contact met je op. Voor vragen over de sollicitatieprocedure kun je contact opnemen met onze recruiter Nikki Gunnink via 06-12656229 of <a href="mailto:nikki.gunnink@devolksbank.nl">nikki.gunnink@devolksbank.nl</a>.</p>\n',
#   'how_to_apply': '<p><a href="https://vonq.io/2XnTUi7">Klik hier om te solliciteren!</a></p>\n',
#   'company_logo': 'https://jobs.github.com/rails/active_storage/blobs/eyJfcmFpbHMiOnsibWVzc2FnZSI6IkJBaHBBc2lCIiwiZXhwIjpudWxsLCJwdXIiOiJibG9iX2lkIn19--ec3cb840e582c4a743b6ac13c0ebde7ccf2000d7/De%20volksbank%20logo.jpeg'},
#  {'id': '4adc96aa-ebf2-49c6-8234-57f8809739cc',
#   'type': 'Full Time',
#   'url': 'https://jobs.github.com/positions/4adc96aa-ebf2-49c6-8234-57f8809739cc',
#   'created_at': 'Thu Apr 09 17:35:05 UTC 2020',
#   'company': 'CrowdStrike',
#   'company_url': 'https://bit.ly/3aTJElH',
#   'location': 'Romania - Bucharest, Brasov, Cluj, Iasi and Timisoara (Remote)',
#   'title': 'DevOps Engineer - Splunk',
#   'description': '<p>At CrowdStrike we’re on a mission - to stop breaches. Our groundbreaking technology, services delivery, and intelligence gathering together with our innovations in machine learning and behavioral-based detection, allow our customers to not only defend themselves, but do so in a future-proof manner. We’ve earned numerous honors and top rankings for our technology, organization and people – clearly confirming our industry leadership and our special culture driving it. We also offer flexible work arrangements to help our people manage their personal and professional lives in a way that works for them. So if you’re ready to work on unrivaled technology where your desire to be part of a collaborative team is met with a laser-focused mission to stop breaches and protect people globally, let’s talk.</p>\n<p><strong>About the Role</strong></p>\n<p>We’re building the next-generation infrastructure and security platform for CrowdStrike which includes an application and service delivery platform, massively scalable distributed data storage and replication systems, and a cutting-edge search and distributed graph system. Help us scale CrowdStrike’s infrastructure and products to handle massive growth in traffic and data as we continue to experience dramatic growth in the usage of our products.</p>\n<p>We are looking for a skilled DevOps Engineer who can contribute to our team which is responsible for thousands of Splunk systems that run in AWS as well as in Crowdstrike data centers. We handle infrastructure, the Splunk backend and some application development, but the latter is handled mostly by a dedicated application development team. Splunk knowledge is an advantage, but if not, don’t worry, we will teach you.</p>\n<p><em>This position is open to candidates in Bucharest (Office or Romania Remote), Brasov, Cluj, Iasi and Timisoara (Remote).</em></p>\n<p><strong>You will:</strong></p>\n<ul>\n<li>Build automation tools for infrastructure using Python and various technologies including\ncontainers</li>\n<li>Participate in, and at times lead, backend engineering efforts from rapid prototypes to large-scale\napplications using Python</li>\n<li>Brainstorm, define, and build collaboratively with members across multiple team</li>\n<li>Obsess about learning, and champion the newest technologies &amp; tricks with others, raising the\ntechnical IQ of the team</li>\n<li>Constantly re-evaluate our product to improve architecture, knowledge models, user experience,\nperformance and stability.</li>\n<li>Be an energetic "self-starter" with the ability to take ownership and be accountable for deliverables</li>\n</ul>\n<p><strong>Key Qualifications:</strong></p>\n<ul>\n<li>Linux systems administration, bash scripting</li>\n<li>Configuration management automation using Chef, Puppet or Salt</li>\n<li>Python scripting, automation through scripts</li>\n</ul>\n<p><strong>Nice to have skills:</strong></p>\n<ul>\n<li>Good knowledge of Splunk search processing language (SPL), reporting, dashboards, and search\nacceleration techniques</li>\n<li>Experience administering Splunk, especially clusters and bundle replication, custom search\ncommands, KV Store</li>\n<li>Javascript</li>\n<li>AWS Cloud</li>\n<li>Container technologies such as Docker, Kubernetes</li>\n<li>Experience programming with the Splunk REST API</li>\n<li>Regular expressions</li>\n<li>Good knowledge of Splunk data ingestion, field extraction and post-ingestion processing</li>\n</ul>\n<p><strong>Benefits of Working at CrowdStrike:</strong></p>\n<ul>\n<li>Market leader in compensation</li>\n<li>Comprehensive health benefits</li>\n<li>Working with the latest technologies</li>\n<li>Training budget (certifications, conferences)</li>\n<li>Flexible work hours and remote friendly environment</li>\n<li>Wellness programs</li>\n<li>Stocked fridges, coffee, soda, and lots of treats</li>\n<li>Peer recognition</li>\n<li>Inclusive culture focused on people, customers and innovation</li>\n<li>Re ...
#   'how_to_apply': '<p><a href="https://bit.ly/2UWIDE7">https://bit.ly/2UWIDE7</a></p>\n',
#   'company_logo': 'https://jobs.github.com/rails/active_storage/blobs/eyJfcmFpbHMiOnsibWVzc2FnZSI6IkJBaHBBc1NCIiwiZXhwIjpudWxsLCJwdXIiOiJibG9iX2lkIn19--f94b42b06ea82f40155cc241a5e2f2ebd79e4689/Capture%20crowdstrike%20logo.PNG'},
#  {'id': '3c62c4a3-7ab7-4b56-9a65-f395d81e8f96',
#   'type': 'Full Time',
#   'url': 'https://jobs.github.com/positions/3c62c4a3-7ab7-4b56-9a65-f395d81e8f96',
#   'created_at': 'Thu Apr 09 17:27:19 UTC 2020',
#   'company': 'CrowdStrike',
#   'company_url': 'https://bit.ly/3aTJElH',
#   'location': 'Romania - Bucharest, Brasov, Cluj, Iasi and Timisoara (Remote)',
#   'title': 'Senior Cloud Software Engineer',
#   'description': "<p>At CrowdStrike we’re on a mission - to stop breaches. Our groundbreaking technology, services delivery, and intelligence gathering together with our innovations in machine learning and behavioral-based detection, allow our customers to not only defend themselves, but do so in a future-proof manner. We’ve earned numerous honors and top rankings for our technology, organization and people – clearly confirming our industry leadership and our special culture driving it. We also offer flexible work arrangements to help our people manage their personal and professional lives in a way that works for them. So if you’re ready to work on unrivaled technology where your desire to be part of a collaborative team is met with a laser-focused mission to stop breaches and protect people globally, let’s talk.</p>\n<p><strong>About the Role:</strong></p>\n<p>The Sr. Software Engineer role is part of the Engineering team from CrowdStrike Romania who will build globally distributed, fault tolerant and highly scalable cloud-based critical systems using Golang.</p>\n<p><strong>Don't worry if you don't know Golang, we will teach you!</strong></p>\n<p>If you are a hands-on engineer who loves to operate at scale, let's talk!</p>\n<p><em>This position is open to candidates in Bucharest (Office or Romania Remote), Brasov, Cluj, Iasi and Timisoara (Remote).</em></p>\n<p><strong>You will:</strong></p>\n<ul>\n<li>Lead backend engineering efforts from rapid prototypes to large-scale application services across\nCrowdStrike products</li>\n<li>Make it possible for internal teams to easily work with data at the petabyte scale</li>\n<li>Leverage and build cloud based services to support our top rated security intelligence platform</li>\n<li>Work with security researchers to troubleshoot time-sensitive production issues</li>\n<li>Keep petabytes of critical business data safe, secure, and available</li>\n<li>Brainstorm, define, and build collaboratively with members across multiple teams</li>\n<li>Obsess about learning, and champion the newest technologies &amp; tricks with others, raising the\ntechnical IQ of the team</li>\n<li>Be mentored and mentor other developers on web, backend and data storage technologies and\nour system</li>\n<li>Constantly re-evaluate our product to improve architecture, knowledge models, user experience,\nperformance and stability</li>\n<li>Be an energetic ‘self-starter’ with the ability to take ownership and be accountable for deliverables</li>\n<li>Use and give back to the open source community</li>\n</ul>\n<p><strong>You'll use:</strong></p>\n<ul>\n<li>Golang</li>\n<li>Python</li>\n<li>Cassandra</li>\n<li>Kafka</li>\n<li>Elasticsearch</li>\n<li>SQL</li>\n<li>Redis</li>\n<li>ZMQ</li>\n<li>Hadoop</li>\n<li>AWS Cloud</li>\n<li>Git</li>\n</ul>\n<p><strong>What You’ll Need:</strong></p>\n<ul>\n<li>Bachelor's Degree in Computer Science (or commensurate experience in data\nstructures/algorithms/distributed systems)</li>\n<li>Strong programming skills – Python / Java / Scala or Golang</li>\n<li>The ability to design scalable and re-usable SOA services</li>\n<li>The ability to scale backend systems – sharding, partitioning, scaling horizontally are second\nnature to you</li>\n<li>The desire to ship code and the love of seeing your bits run in production</li>\n<li>Deep understanding of distributed systems and scalability challenges</li>\n<li>Deep understand multi-threading, concurrency, and parallel processing technologies</li>\n<li>Team player skills – we embrace collaborating as a team as much as possible</li>\n<li>A thorough understanding of engineering best practices from appropriate testing paradigms to\neffective peer code reviews and resilient architecture</li>\n<li>The ability to thrive in a fast paced, test-driven, collaborative and iterative programming\nenvironment</li>\n<li>The skills to meet your commitments on time and produce high quality software that is unit tested,\ncode reviewed, and checked in regularl ...
#   'how_to_apply': '<p><a href="https://bit.ly/3ebgiRO">https://bit.ly/3ebgiRO</a></p>\n',
#   'company_logo': 'https://jobs.github.com/rails/active_storage/blobs/eyJfcmFpbHMiOnsibWVzc2FnZSI6IkJBaHBBc0tCIiwiZXhwIjpudWxsLCJwdXIiOiJibG9iX2lkIn19--e1785f81d8af2cd50c3976f77f273e74cc84c0b6/Capture%20crowdstrike%20logo.PNG'},
#  {'id': 'f7432ea9-6552-4076-a8fd-1e0143ccf8f5',
#   'type': 'Full Time',
#   'url': 'https://jobs.github.com/positions/f7432ea9-6552-4076-a8fd-1e0143ccf8f5',
#   'created_at': 'Thu Apr 09 17:15:25 UTC 2020',
#   'company': 'CrowdStrike',
#   'company_url': 'https://bit.ly/3aTJElH',
#   'location': 'Romania -  Bucharest, Brasov, Cluj, Iasi and Timisoara (Remote)',
#   'title': 'Big Data Engineer',
#   'description': '<p>At CrowdStrike we’re on a mission - to stop breaches. Our groundbreaking technology, services delivery, and intelligence gathering together with our innovations in machine learning and behavioral-based detection, allow our customers to not only defend themselves, but do so in a future-proof manner. We’ve earned numerous honors and top rankings for our technology, organization and people – clearly confirming our industry leadership and our special culture driving it. We also offer flexible work arrangements to help our people manage their personal and professional lives in a way that works for them. So if you’re ready to work on unrivaled technology where your desire to be part of a collaborative team is met with a laser-focused mission to stop breaches and protect people globally, let’s talk.</p>\n<p><strong>About the Role</strong></p>\n<p>We are looking to hire a Big Data Engineer for the Data Engineering team at CrowdStrike. The Data Engineering team operates within the Data Science organization, and provides the necessary infrastructure and automation for users to analyze and act on vast quantities of data effortlessly. The team has one of the most critical roles to play in ensuring our products are best-in-class in the industry. You will interact with product managers and other engineers in building both internal and external facing services.</p>\n<p><em>This position is open to candidates in Bucharest (Office or Romania Remote), Brasov, Cluj, Iasi and Timisoara (Remote)</em></p>\n<p><strong>You will:</strong></p>\n<ul>\n<li>Write jobs using PySpark to process billions of events per day</li>\n<li>Fine tune existing Hadoop / Spark clusters</li>\n<li>Rewrite some existing PIG jobs in PySpark</li>\n</ul>\n<p><strong>Key Qualifications</strong></p>\n<p><strong>You have:</strong></p>\n<ul>\n<li>BS degree in Computer Science or related field</li>\n<li>7+ years of relevant work experience</li>\n<li>Experience in building data pipelines at scale (Note: We process over 1 Trillion events per week)</li>\n<li>Good knowledge of Hadoop / Spark /Apache Kafka, Python, AWS, PySpark and other tools in the\nBig Data ecosystem</li>\n<li>Good programming skills – Python</li>\n<li>Operation experience in the tuning of clusters for optimal data processing</li>\n<li>Experience in building out ETL jobs at scale</li>\n<li>Good knowledge of distributed system design and associated tradeoffs</li>\n<li>Good knowledge of CI / CD and associated best practices</li>\n<li>Familiarity with Docker-based development and orchestration</li>\n</ul>\n<p><strong>Bonus points awarded if you have:</strong></p>\n<ul>\n<li>Created automated / scalable infrastructure and pipelines for teams in the past</li>\n<li>Contributed to the open source community (GitHub, Stack Overflow, blogging)</li>\n<li>Prior experience with Spinnaker, Relational DBs, or KV Stores</li>\n<li>Prior experience in the cybersecurity or intelligence fields</li>\n</ul>\n<p><strong>Benefits of Working at CrowdStrike:</strong></p>\n<ul>\n<li>Market leader in compensation</li>\n<li>Comprehensive health benefits</li>\n<li>Working with the latest technologies</li>\n<li>Training budget (certifications, conferences)</li>\n<li>Flexible work hours and remote friendly environment</li>\n<li>Wellness programs</li>\n<li>Stocked fridges, coffee, soda, and lots of treats</li>\n<li>Peer recognition</li>\n<li>Inclusive culture focused on people, customers and innovation</li>\n<li>Regular team activities, including happy hours, community service events</li>\n</ul>\n<p>We are committed to building an inclusive culture of belonging that not only embraces the diversity of our people but also reflects the diversity of the communities in which we work and the customers we serve. We know that the happiest and highest performing teams include people with diverse perspectives and ways of solving problems so we strive to attract and retain talent from all backgrounds and create workplaces where everyone f ...
#   'how_to_apply': '<p><a href="https://bit.ly/3c3W6Q1">https://bit.ly/3c3W6Q1</a></p>\n',
#   'company_logo': 'https://jobs.github.com/rails/active_storage/blobs/eyJfcmFpbHMiOnsibWVzc2FnZSI6IkJBaHBBcitCIiwiZXhwIjpudWxsLCJwdXIiOiJibG9iX2lkIn19--8fb3f6ea426896fbef33af2c6686191f2d6d9781/Capture%20crowdstrike%20logo.PNG'},
#  {'id': 'eb810ceb-c070-4395-a56c-f3148a6f59cc',
#   'type': 'Full Time',
#   'url': 'https://jobs.github.com/positions/eb810ceb-c070-4395-a56c-f3148a6f59cc',
#   'created_at': 'Thu Apr 09 17:07:05 UTC 2020',
#   'company': 'CrowdStrike',
#   'company_url': 'https://bit.ly/3aTJElH',
#   'location': 'Romania - Bucharest, Brasov, Cluj, Iasi and Timisoara (Remote).',
#   'title': 'Site Reliability Engineer',
#   'description': "<p>At CrowdStrike we’re on a mission - to stop breaches. Our groundbreaking technology, services delivery, and intelligence gathering together with our innovations in machine learning and behavioral-based detection, allow our customers to not only defend themselves, but do so in a future-proof manner. We’ve earned numerous honors and top rankings for our technology, organization and people – clearly confirming our industry leadership and our special culture driving it. We also offer flexible work arrangements to help our people manage their personal and professional lives in a way that works for them. So if you’re ready to work on unrivaled technology where your desire to be part of a collaborative team is met with a laser-focused mission to stop breaches and protect people globally, let’s talk.</p>\n<p><strong>About the Role</strong></p>\n<p>At CrowdStrike we operate a massive cloud platform that protects our customers from a variety of bad actors: cyber criminals, hacktivists and state sponsored attackers. We process tens of billions of events a day and we store and use petabytes of data. We’re looking for an engineer who is passionate about site reliability and is excited about joining us to ensure our service runs 24/7.</p>\n<p><em>This position is open to candidates in Bucharest (Office or Romania Remote), Brasov, Cluj, Iasi and Timisoara (Remote).</em></p>\n<p><strong>You will:</strong></p>\n<ul>\n<li>Be responsible for all operational aspects of our platform -  Availability, Latency, Throughput,\nMonitoring, Issue Response (analysis, remediation, deployment) and Capacity Planning with\nrespect to Latency and Throughput.  Build tooling to help monitor and analyze the platform</li>\n<li>Work in a team of highly motivated engineers</li>\n<li>Use your passion for technology to ensure our platform operates flawlessly 24x7</li>\n<li>Obsess about learning, and champion the newest technologies &amp; tricks with others, raising the\ntechnical IQ of the team. We don’t expect you to know all the technology we use but you will be\nable to get up to speed on new technology quickly</li>\n<li>Have broad exposure to our entire architecture and become one of our experts in overall process\nflow</li>\n<li>Be a great code reader and debugger, you will have to dive into large code bases, identify issues\nand remediate</li>\n<li>Have an intrinsic drive to make things better</li>\n<li>Bias towards small development projects and the occasional larger project</li>\n<li>Use and give back to the open source community</li>\n</ul>\n<p><strong>You'll use:</strong></p>\n<ul>\n<li>Go(Golang)</li>\n<li>Python</li>\n<li>ElasticSearch</li>\n<li>Cassandra</li>\n<li>Kafka</li>\n<li>Redis, Memcached</li>\n<li>AWS Cloud</li>\n</ul>\n<p><strong>Key Qualifications:</strong></p>\n<p><strong>You have:</strong></p>\n<ul>\n<li>Degree in Computer Science (or commensurate experience in data\nstructures/algorithms/distributed systems).</li>\n<li>Experience as a sustaining engineering or SRE for a cloud based product.</li>\n<li>Good understanding of distributed systems and scalability challenges – sharding, partitioning,\nscaling horizontally are second nature to you.</li>\n<li>A thorough understanding of engineering best practices from appropriate testing paradigms to\neffective peer code reviews and resilient architecture.</li>\n<li>The ability to thrive in a fast paced, test-driven, collaborative and iterative programming\nenvironment.</li>\n<li>Good understand of multi-threading, concurrency, and parallel processing technologies.</li>\n<li>The skills to meet your commitments on time and produce high quality software that is unit tested,\ncode reviewed, and checked in regularly for continuous integration.</li>\n<li>Team player skills – we embrace collaborating as a team as much as possible.</li>\n</ul>\n<p><strong>Bonus points awarded for:</strong></p>\n<ul>\n<li>Contributions to the open source community (GitHub, Stack Overflow, blogging).</li>\ ...
#   'how_to_apply': '<p><a href="https://bit.ly/2xY3dLk">https://bit.ly/2xY3dLk</a></p>\n',
#   'company_logo': 'https://jobs.github.com/rails/active_storage/blobs/eyJfcmFpbHMiOnsibWVzc2FnZSI6IkJBaHBBcjJCIiwiZXhwIjpudWxsLCJwdXIiOiJibG9iX2lkIn19--6437dedc949c54f10fe0035629d0183ca4d3f3a1/Capture%20crowdstrike%20logo.PNG'},
#  {'id': '86e5717f-6ee3-41e4-8141-892a91d23814',
#   'type': 'Full Time',
#   'url': 'https://jobs.github.com/positions/86e5717f-6ee3-41e4-8141-892a91d23814',
#   'created_at': 'Thu Apr 09 16:53:26 UTC 2020',
#   'company': 'CrowdStrike',
#   'company_url': 'https://bit.ly/3aTJElH',
#   'location': 'Romania - Bucharest, Cluj, Brasov and Isai (Remote)',
#   'title': 'Sr. Data Engineer',
#   'description': '<p>At CrowdStrike we’re on a mission - to stop breaches. Our groundbreaking technology, services delivery, and intelligence gathering together with our innovations in machine learning and behavioral-based detection, allow our customers to not only defend themselves, but do so in a future-proof manner. We’ve earned numerous honors and top rankings for our technology, organization and people – clearly confirming our industry leadership and our special culture driving it. We also offer flexible work arrangements to help our people manage their personal and professional lives in a way that works for them. So if you’re ready to work on unrivaled technology where your desire to be part of a collaborative team is met with a laser-focused mission to stop breaches and protect people globally, let’s talk.</p>\n<p><strong>About the Role</strong></p>\n<p>We are looking to hire a Sr. Data Engineer for the Data Engineering team at CrowdStrike. The Data Engineering team operates within the Data Science organization, and provides the necessary infrastructure and automation for users to analyze and act on vast quantities of data effortlessly. The team has one of the most critical roles to play in ensuring our products are best-in-class in the industry. You will interact with product managers and other engineers in building both internal and external facing services.</p>\n<p><em>This role is open to candidates in Bucharest, (Office or Remote) Cluj, Brasov and Isai (Remote).</em></p>\n<p><strong>What You’ll Need</strong></p>\n<ul>\n<li>BS degree in Computer Science or related field.</li>\n<li>7+ years of relevant work experience.</li>\n<li>Good knowledge of some (or all) of AWS, Python, Golang , Kafka , Spark, Airflow, ECS,\nKubernetes, etc to build infrastructure that can ingest and analyze billions of events per day.</li>\n<li>Good knowledge of distributed system design and associated tradeoffs.</li>\n<li>Good knowledge of CI / CD and associated best practices.</li>\n<li>Familiarity with Docker-based development and orchestration.</li>\n</ul>\n<p><strong>Bonus points if you have…</strong></p>\n<ul>\n<li>Created automated / scalable infrastructure and pipelines for teams in the past.</li>\n<li>Contributed to the open source community (GitHub, Stack Overflow, blogging).</li>\n<li>Prior experience with Spinnaker, Relational DBs, or KV Stores.</li>\n<li>Prior experience in the cybersecurity or intelligence fields.</li>\n</ul>\n<p><strong>Benefits of Working at CrowdStrike:</strong></p>\n<ul>\n<li>Market leader in compensation</li>\n<li>Comprehensive health benefits + 401k plan (US only)</li>\n<li>Flexible work hours and remote friendly environment</li>\n<li>Wellness programs</li>\n<li>Stocked fridges, coffee, soda, and snacks</li>\n<li>Peer recognition</li>\n<li>Inclusive culture focused on people, customers and innovation</li>\n<li>Regular team activities, including happy hours, community service events</li>\n</ul>\n<p>We are committed to building an inclusive culture of belonging that not only embraces the diversity of our people but also reflects the diversity of the communities in which we work and the customers we serve. We know that the happiest and highest performing teams include people with diverse perspectives and ways of solving problems so we strive to attract and retain talent from all backgrounds and create workplaces where everyone feels empowered to bring their full, authentic selves to work.</p>\n<p>CrowdStrike is an Equal Opportunity employer. All qualified applicants will receive consideration for employment without regard to race, color, religion, sex including sexual orientation and gender identity, national origin, disability, protected veteran status, or any other characteristic protected by applicable federal, state, or local law.</p>\n',
#   'how_to_apply': '<p><a href="https://bit.ly/3aWLphX">https://bit.ly/3aWLphX</a></p>\n',
#   'company_logo': 'https://jobs.github.com/rails/active_storage/blobs/eyJfcmFpbHMiOnsibWVzc2FnZSI6IkJBaHBBcnFCIiwiZXhwIjpudWxsLCJwdXIiOiJibG9iX2lkIn19--94dd29504f03eb37c91c984a38525afa7004064e/Capture%20crowdstrike%20logo.PNG'},
#  {'id': '5ea390c8-c3c1-4b2a-a325-12be05dc5281',
#   'type': 'Full Time',
#   'url': 'https://jobs.github.com/positions/5ea390c8-c3c1-4b2a-a325-12be05dc5281',
#   'created_at': 'Thu Apr 09 16:43:11 UTC 2020',
#   'company': 'CrowdStrike ',
#   'company_url': 'https://bit.ly/3aTJElH',
#   'location': 'Romania - Bucharest, Brasov, Cluj and Isai (Remote)',
#   'title': 'Senior Backend Engineer - Mobile Sensor',
# ...
#   'how_to_apply': '<p>Please submit a cover letter and resume/vitae formatted in PDF or Microsoft Word to <a href="mailto:jobs@clarkstate.edu">jobs@clarkstate.edu</a>. Reference the position title in the first line of the cover letter.</p>\n',
#   'company_logo': 'https://jobs.github.com/rails/active_storage/blobs/eyJfcmFpbHMiOnsibWVzc2FnZSI6IkJBaHBBaDZCIiwiZXhwIjpudWxsLCJwdXIiOiJibG9iX2lkIn19--bb2f512c3a03ed709a61aa1e6a3cc6d7c5a1bf14/Clark_State_Primary-color-logo.jpg'},
#  {'id': 'c01aa7e9-3e7f-4e21-813a-0e48b6bddf22',
#   'type': 'Full Time',
#   'url': 'https://jobs.github.com/positions/c01aa7e9-3e7f-4e21-813a-0e48b6bddf22',
#   'created_at': 'Wed Mar 25 09:01:53 UTC 2020',
#   'company': 'SGS Maco',
#   'company_url': 'https://www.smartrecruiters.com/SGS/743999709559608-software-developer',
#   'location': 'Herten',
#   'title': 'Software Developer',
#   'description': '<p>Ben jij de developer die de materie van internationale handel interessant vindt en in staat is om met douane-experts softwareoplossingen te bouwen? Dan is dit jouw nieuwe baan! Sluit je aan bij SGS Maco.</p>\n<p>Software Developer\nFulltime | Herten</p>\n<p>Wie zijn wij?\nSGS Maco Customs Service helpt bedrijven die internationaal handel drijven om zo eenvoudig mogelijk te voldoen aan hun douaneverplichtingen. Dat doen wij met een groot team van ervaren douanedeclaranten die bedrijven helpen met hun aangiften. En door slimme software oplossingen te bedenken die de aangifte processen ondersteunen of automatiseren.</p>\n<p>Onze douanedeclaranten en ons software team werken elke dag intensief samen om gebruiksvriendelijke aangiftesoftware te maken, processen te digitaliseren en interfaces te bouwen met klanten die hun aangiften willen automatiseren.</p>\n<p>Brexit, handelsverdragen, sancties, verscherpte handhaving, aanpassingen in de systemen van de overheden, veranderende wetgeving en onze eigen ambities om binnen en buiten de Benelux verder te groeien zorgen voor een onophoudelijke stroom aan uitdagende softwareprojecten. Om verder te kunnen groeien willen wij ons software team versterken.</p>\n<p>Het software team is een hecht team dat intensief samenwerkt vanuit onze vestigingen in Roermond, Spijkenisse en Antwerpen. Jouw standplaats wordt bij voorkeur Roermond.</p>\n<p>SGS Maco kenmerkt zich door een platte organisatie, oplossingsgerichtheid, klantgerichtheid en bereidheid om elkaar te helpen.</p>\n<p>Geen werkdag is hetzelfde.\nJij bent de software developer die de materie van internationale handel interessant vindt en in staat is om samen met douane-experts softwareoplossingen te bouwen die de grenzen van automatisering in de markt verleggen. Je zorgt ervoor dat onze systemen optimaal blijven functioneren en elke dag beter worden door de ontwikkeling van software en applicaties. Je krijgt energie van nieuwe dingen bouwen, houdt van slimmer werken.\nVoorbeeldprojecten:</p>\n<ul>\n<li>Het automatiseren van de opvolging van vooraf aangiften door slim gebruik te maken van dataservices van ketenpartners;</li>\n<li>Het implementeren van een nieuwe berichtenstroom met een overheidssysteem waarmee nieuwe dienstverlening mogelijk gemaakt wordt;</li>\n<li>Onze douanesoftware uitbreiden met de mogelijkheid om in een andere EU-lidstaat aangiften te maken;</li>\n<li>Het stapsgewijs herstructureren en ombouwen van ons softwareplatform naar een modulaire oplossing met minder redundancy en minder onderhoud om sneller nieuwe functionaliteiten te kunnen aanbieden.</li>\n</ul>\n<p>Wat breng je mee?\nOm als software developer goed beslagen ten ijs te komen, heb je een minimaal een afgeronde IT (gerelateerde) hbo-opleiding en minstens 3 jaar relevante werkervaring bij voorkeur opgedaan binnen de douane branche. Je hebt ervaring met C#, ASP.NET, JavaScript, JQuery, REST API’s, SQL en bent bekend met test driven development. Daarnaast heb je ervaring met agile werken en ben je in staat om je snel nieuwe technologieën eigen te maken en deze toe te passen in de dagelijkse praktijk.</p>\n<p>Je hebt een groot verantwoordelijkheidsgevoel en neemt graag het initiatief. Je bent graag betrokken bij alle aspecten van softwareontwikkeling (analyse, realisatie, support). Je wordt van niets blijer dan van ontwikkelen van nieuwe software en dat ook nog in een gezellig team. Je bent gemotiveerd om te blijven leren en wilt vanuit jouw expertise meebouwen aan de groei van SGS Maco.</p>\n<p>Mooie vooruitzichten.\nSGS Maco biedt je een functie met de nodige verantwoordelijkheid. Jouw salaris is marktconform en sluit aan bij de ervaring die jij meebrengt. Daarnaast bieden we je een goed pakket van secundaire arbeidsvoorwaarden, zoals:</p>\n<ul>\n<li>Een fulltime functie voor 40 uur, minder is bespreekbaar tot een minimum van 32 uur;</li>\n<li>Je krijgt de ruimte om de inhoud in te duiken;</li>\n<li>Een aanstelling met uitzicht op een vast die ...
#   'how_to_apply': '<p>Solliciteer via de sollicitatiebutton.</p>\n',
#   'company_logo': 'https://jobs.github.com/rails/active_storage/blobs/eyJfcmFpbHMiOnsibWVzc2FnZSI6IkJBaHBBaHlCIiwiZXhwIjpudWxsLCJwdXIiOiJibG9iX2lkIn19--c0c342360465d4f7f700962329730e7a2000cdae/logo-vierkant.jpg'},
#  {'id': '8aefdfc5-0676-4b0d-9c22-dd27d5a4ddcb',
#   'type': 'Full Time',
#   'url': 'https://jobs.github.com/positions/8aefdfc5-0676-4b0d-9c22-dd27d5a4ddcb',
#   'created_at': 'Tue Mar 24 18:32:35 UTC 2020',
#   'company': 'RiverCap Holdings, LLC.',
#   'company_url': 'https://www.rivercapllc.com/',
#   'location': 'Rocky River, Ohio',
#   'title': 'Director of Software Development',
#   'description': "<p>Description:</p>\n<p>RiverCap Holdings is a holding company with its headquarters in Rocky River, Ohio. RiverCap's portfolio consists of our virtual platform, ExchangeBase, our capital group, RiverCap Ventures, and our technology company, Zullix that has built and continues to develop our technology.</p>\n<p>Our proprietary technology is the foundation for the ExchangeBase Platform which connects thousands of users in the Energy industry with unmatched visibility to assets, services and requests. This technology has a CRM component that helps ExchangeBase employees to drive user activity and to help customers buy and sell assets through on the Platform. To help enhance this technology, we are looking for a Director of Software Development with experience managing teams and in .NET stack, C#, and Microsoft Azure.</p>\n<p>Our technology team works to optimize the way our CRM component communicates with the Platform allowing ExchangeBase employees to help users transact.</p>\n<p>The customers of our technology team are the sister companies of Zullix: RiverCap Holdings, RiverCap Ventures, and ExchangeBase.</p>\n<p>Our technology team develops solutions to customer needs and is continually improving the experience of our users on the Platform.</p>\n<p>Our Director of Software Development will work closely with business leaders at RiverCap and its portfolio companies to develop and improve technology-based processes.</p>\n<p>Requirements:</p>\n<p>Supervise project management for the full software development lifecycle and implementation of technical activities that ensure successful project completion</p>\n<p>Build and maintain positive relationships with cross functional teams to work effectively with technical and non-technical stakeholders</p>\n<p>Oversee all project deliverables to ensure quality and accuracy meet project and stakeholder standards and deadlines</p>\n<p>Execute all project management functions, including work breakdown, scheduling, monitoring and tracking of development progress against the defined timetables, budgets, and team assignments</p>\n<p>Manage team development by holding teams accountable for their commitments and removing roadblocks to their work</p>\n<p>Manages project work teams and the development and integration of project deliverables.</p>\n<p>Sets objectives and priorities, assigns and reviews tasks, performance and staffing requirements.</p>\n<p>Establish detailed direction during various stages of the development lifecycle to include requirements analysis, testing, and potentially programming support</p>\n<p>Analyze complex business needs presented by the user community and/or customers and recommend technical solutions</p>\n<p>Ensure the consistency and sustainability of existing applications by creating, maintaining, and enforcing standards/procedures for implementing technical solutions</p>\n<p>Assist with directing operations in executing production tasks according to a documented schedule that meets or exceeds user/customer expectations</p>\n<p>Produce detailed timeline for each application release and implement effective project control by monitoring the progress of the software release and providing status reports to management</p>\n<p>Assist with directing and prioritizing the workload of additional personnel</p>\n<p>Perform liaison duties between operations and programming personnel in the areas of systems design, modifications or trouble shooting</p>\n<p>Strong interpersonal skills with the ability to interact and communicate effectively across all levels of the organization</p>\n<p>Recommend policies and procedures to enhance operations</p>\n<p>Create a culture of proactive energy, driven success, and goal achievement</p>\n<p>Assist in organization of project management software and collection of project updates</p>\n<p>Document all processes and project timelines</p>\n<p>Create visual representations of client needs</p>\n<p>Act as a liaison between the Technica ...
#   'how_to_apply': '<p>Please apply using the following link. We look forward to seeing your application!\n<a href="https://apply.workable.com/rivercap-holdings/j/4963682CCC/">https://apply.workable.com/rivercap-holdings/j/4963682CCC/</a></p>\n',
#   'company_logo': 'https://jobs.github.com/rails/active_storage/blobs/eyJfcmFpbHMiOnsibWVzc2FnZSI6IkJBaHBBaGlCIiwiZXhwIjpudWxsLCJwdXIiOiJibG9iX2lkIn19--e96b5ac512f92e1129b74b7f43f7a56ba2f76f3c/ExchangeBase-Logo.png'},
#  {'id': 'e19ba748-fe19-4a8e-bce1-ac824da3cf85',
#   'type': 'Full Time',
#   'url': 'https://jobs.github.com/positions/e19ba748-fe19-4a8e-bce1-ac824da3cf85',
#   'created_at': 'Tue Mar 24 09:00:37 UTC 2020',
#   'company': 'InnoGames GmbH',
#   'company_url': 'https://www.innogames.com',
#   'location': 'Hamburg',
#   'title': '(Senior) Security Engineer',
#   'description': '<p>As <strong>Security Engineer</strong> at InnoGames you will be responsible for auditing, testing and adapting the security systems of our games and our infrastructure. No worries, you won’t be on your own: You will join our experienced Security Engineer who is looking forward to team up. The two of you will improve and maintain the company’s technical security and, of course, you will work closely with all departments to reduce risks of security incidents.</p>\n<p><strong>Your mission:</strong></p>\n<ul>\n<li>You hack all the things!</li>\n<li>You perform internal security audits and penetration tests to discover new weaknesses</li>\n<li>You guide internal teams in security-related topics</li>\n<li>You ensure security requirements are useful and appreciated within the company</li>\n<li>You maintain security standards, guidelines and processes for our systems and infrastructure</li>\n<li>You review vulnerability reports submitted through our bug bounty program</li>\n<li>You participate in designing and reviewing security concepts (new systems, services and applications)</li>\n<li>You develop technical solutions and new security tools to help mitigate security vulnerabilities and automate repeatable tasks</li>\n<li>You perform awareness trainings and workshops</li>\n<li>You coordinate external compliance requirements such as PCI DSS</li>\n</ul>\n<p><strong>Your profile:</strong></p>\n<ul>\n<li>You are experienced preventing different forms of vulnerability across different technologies (e.g. buffer overflows, cross-site scripting)</li>\n<li>You are offering good knowledge of web security mechanisms (Same Origin Policy, CORS etc.)</li>\n<li>You are used to (or at least capable of) communicating and presenting in English (verbal and written)</li>\n</ul>\n<p><em>In addition, you bring some of the following nice-to-have’s</em></p>\n<ul>\n<li>Experience in developing and testing web applications</li>\n<li>Experience in administrating application servers and computer networks</li>\n<li>Interest to research new technologies</li>\n<li>Certificates like GPEN or OSCP</li>\n<li>Participation in a bug bounty program or CTF</li>\n</ul>\n<p><strong>Why join us?</strong></p>\n<ul>\n<li>You’ll work in a multicultural team – enabling you to form and actively optimize work processes</li>\n<li>We actively support personal development, pay for any necessary textbooks as well as sending you to Developer conferences</li>\n<li>You can set up your workspace as you wish: Mac, Linux or Windows, two or more monitors, a free choice of IDE as well as other software</li>\n<li>We provide you with a mobile device (e.g. iPhone or iPad) for private use</li>\n<li>You can take creative breaks: play table tennis with your team, play on our arcade machines, work out in our gym or simply go to our rooftop terrace to get some fresh air</li>\n<li>We contribute to your public transportation ticket and subsidize contributions to the company pension plan</li>\n<li>We offer free drinks and fresh fruit to contribute to your health and wellbeing</li>\n<li>We have regular team events (e.g. curling, cooking, paintball), barbecue together on our rooftop terrace and a company-organized after work get together every Thursday</li>\n<li>We offer trust-based working times in a modern office in the center of Hamburg</li>\n<li>Our company language is English, and we support all our employees and their partners with optional German lessons</li>\n<li>We help you relocate to Hamburg</li>\n<li>We have fun at work!</li>\n</ul>\n<p>Are you excited to start your journey with InnoGames and join our dynamic team as a <strong>Security Engineer</strong>? We look forward to receiving your application (cover letter &amp; CV) as well as your salary expectations and earliest possible starting date through our <a href="https://www.innogames.com/career/detail/job/-senior-security-engineer/?s=Github">online application form</a>. <strong>Maximilian Kaeding</strong> would be happy to ...
#   'how_to_apply': '<p><a href="https://www.innogames.com/career/detail/job/-senior-security-engineer/?s=Github">https://www.innogames.com/career/detail/job/-senior-security-engineer/?s=Github</a></p>\n',
#   'company_logo': 'https://jobs.github.com/rails/active_storage/blobs/eyJfcmFpbHMiOnsibWVzc2FnZSI6IkJBaHBBaE9CIiwiZXhwIjpudWxsLCJwdXIiOiJibG9iX2lkIn19--97e8e6acbb8ccbcd7aed4b82084acf772ff426f9/logo_innogames.png'}]

# %%
r = requests.get(base_site, params = {'page' : 2})

# %%
r
# Out:
# <Response [200]>

# %%
r.json()
# Out:
# [{'id': 'e67ec1f1-bdac-4e4b-901f-7e9934d816e5',
#   'type': 'Full Time',
#   'url': 'https://jobs.github.com/positions/e67ec1f1-bdac-4e4b-901f-7e9934d816e5',
#   'created_at': 'Tue Mar 24 08:50:31 UTC 2020',
#   'company': 'InnoGames GmbH',
#   'company_url': 'https://www.innogames.com',
#   'location': 'Hamburg',
#   'title': 'Security Engineer (special opportunity for Software Developers/Linux Admins)',
#   'description': '<p><strong>You have been working in Software Development or Linux Administration for years, but you are eager to move into a career as Security Engineer and you are knowledgeable about IT security?</strong></p>\n<p>At InnoGames you can continue your career as <strong>Security Engineer</strong>:\nYou will be responsible for auditing, testing and adapting the security systems of our games and our infrastructure. No worries, you won’t be on your own: You will join our experienced Security Engineer who is looking forward to team up. The two of you will improve and maintain the company’s technical security and, of course, you will work closely with all departments to reduce risks of security incidents.</p>\n<p><strong>Your mission:</strong></p>\n<ul>\n<li>You hack all the things!</li>\n<li>You perform internal security audits and penetration tests to discover new weaknesses</li>\n<li>You guide internal teams in security-related topics</li>\n<li>You ensure security requirements are useful and appreciated within the company</li>\n<li>You maintain security standards, guidelines and processes for our systems and infrastructure</li>\n<li>You review vulnerability reports submitted through our bug bounty program</li>\n<li>You participate in designing and reviewing security concepts (new systems, services and applications)</li>\n<li>You develop technical solutions and new security tools to help mitigate security vulnerabilities and automate repeatable tasks</li>\n<li>You perform awareness trainings and workshops</li>\n<li>You coordinate external compliance requirements such as PCI DSS</li>\n</ul>\n<p><strong>Your profile:</strong></p>\n<ul>\n<li>You are knowledgable about the devops toolchain and you are experienced in both, developing and testing web applications, ideally using Django, Spring or Symfony</li>\n</ul>\n<p><strong>OR</strong></p>\n<ul>\n<li>You know your way around a linux console, config management systems like puppet, all the *stat, *trace and *dump tools and the other side of the devops toolchain</li>\n<li>You are interested in researching new technologies and have a soft spot for security</li>\n<li>You are used to (or at least capable of) communicating and presenting in English (verbal and written)</li>\n</ul>\n<p><em>In addition, you bring some of the following nice-to-have’s</em></p>\n<ul>\n<li>Good knowledge of vulnerability across different technologies (e.g. buffer overflows, cross-site scripting)</li>\n<li>Good knowledge of web security mechanisms (Same Origin Policy, CORS etc.)</li>\n<li>Certificates like GPEN or OSCP</li>\n<li>Participation in a bug bounty program or CTF</li>\n</ul>\n<p><strong>Why join us?</strong></p>\n<ul>\n<li>You’ll work in a multicultural team – enabling you to form and actively optimize work processes</li>\n<li>We actively support personal development, pay for any necessary textbooks as well as sending you to Developer conferences</li>\n<li>You can set up your workspace as you wish: Mac, Linux or Windows, two or more monitors, a free choice of IDE as well as other software</li>\n<li>We provide you with a mobile device (e.g. iPhone or iPad) for private use</li>\n<li>You can take creative breaks: play table tennis with your team, play on our arcade machines, work out in our gym or simply go to our rooftop terrace to get some fresh air</li>\n<li>We contribute to your public transportation ticket and subsidize contributions to the company pension plan</li>\n<li>We offer free drinks and fresh fruit to contribute to your health and wellbeing</li>\n<li>We have regular team events (e.g. curling, cooking, paintball), barbecue together on our rooftop terrace and a company-organized after work get together every Thursday</li>\n<li>We offer trust-based working times in a modern office in the center of Hamburg</li>\n<li>Our company language is English, and we support all our employees and their partners with optional German lessons</li>\n<li>We help you relocate to Hamburg</li>\n<li>We ...
#   'how_to_apply': '<p><a href="https://www.innogames.com/career/detail/job/security-engineer-special-opportunity-for-software-developers-linux-admins-/?s=Github">https://www.innogames.com/career/detail/job/security-engineer-special-opportunity-for-software-developers-linux-admins-/?s=Github</a></p>\n',
#   'company_logo': 'https://jobs.github.com/rails/active_storage/blobs/eyJfcmFpbHMiOnsibWVzc2FnZSI6IkJBaHBBaENCIiwiZXhwIjpudWxsLCJwdXIiOiJibG9iX2lkIn19--5cce6a1bfec03de620cfb070347de6a895e149a5/logo_innogames.png'},
#  {'id': 'b00d6709-2220-4c88-bac2-3f61588b7039',
#   'type': 'Full Time',
#   'url': 'https://jobs.github.com/positions/b00d6709-2220-4c88-bac2-3f61588b7039',
#   'created_at': 'Mon Mar 23 20:37:09 UTC 2020',
#   'company': 'Analytics Fire',
#   'company_url': 'http://afdc.co/',
#   'location': 'Remote',
#   'title': 'Senior Embedded Linux Developer with C/C++ -- 100% Remote, Flexible hours',
#   'description': '<p><strong>Job Description</strong></p>\n<p>Analytics Fire builds custom software for the solar power industry. We’re looking for a senior embedded developer with deep experience developing, testing, and debugging embedded software in a Linux environment to help us expand our services to support manufacturers in clean energy and other high-tech sectors.</p>\n<p>Analytics Fire is a small, distributed team working on a range of interesting projects. For example, we recently helped build a custom IoT platform for utility grade solar power plants, sales software for residential solar systems, and a machine-learning powered autonomous cleaning robot. We’re looking for a fun, reliable, and highly collaborative, senior developer to join our team.</p>\n<p>This is a remote position. We’re flexible about location and hours, so long as your working hours are within a European or US-overlapping time zone. We’re a really great match for a senior developer who wants to work hard on interesting projects, while simultaneously having flexibility around time and geography.</p>\n<p><strong>Skills &amp; Requirements</strong></p>\n<p>Ideally, you should have 5+ years developing, testing, and debugging embedded software in a Linux environment. You should be comfortable autonomously driving your own high quality / high velocity contributions using a range of technologies.</p>\n<p>Required skills:</p>\n<ul>\n<li>Expert level experience developing, testing and debugging embedded software in a Linux environment</li>\n<li>Development experience using Python, C, and C++</li>\n<li>Basic hardware experience (cabling, basic troubleshooting)</li>\n<li>Basic understanding of web technology</li>\n<li>Strong verbal and written communication skills</li>\n</ul>\n<p>Nice to have:</p>\n<ul>\n<li>Expert-level network systems experience using connman, BTLE, and dbus</li>\n<li>Expert-level experience with wireless protocols (eg zigbee, cellular modem, etc)</li>\n<li>Intermediate or expert level security engineering experience with current knowledge of security best practices, common exploits, and threat landscape</li>\n<li>Previous experience creating custom Linux-based systems using Yocto</li>\n</ul>\n<p>Analytics Fire has a very polyglot technical culture. Our ideal candidate has expert-level skills in the above categories, but also have a secondary skill set in one of the following areas:</p>\n<ul>\n<li>Full stack software engineering with React, Angular</li>\n<li>Scientific computing with C++ and/or Python</li>\n<li>Computer vision / machine learning (PhD-level)</li>\n<li>DevOps automation</li>\n</ul>\n<p><strong>About Analytics Fire</strong></p>\n<p>Analytics Fire was founded by a couple of engineering nerds -- one a PHd in machine learning and the other a former VP of Engineering for an analytics platform -- who both are also serial entrepreneurs backed by prominent angels and VCs including Y Combinator and 500 Startups.</p>\n<p>“Our goal founding Analytics Fire, was to create the engineering department that we always dreamed of working for. For us this meant being able to spend our time working on the hardest and most interesting technical problems that we could find, being part of a small, tightly-knit team of world-class engineers, while simultaneously having flexibility around time and geography.”</p>\n',
#   'how_to_apply': '<p>Email your resume to <a href="mailto:join-us@analyticsfire.com">join-us@analyticsfire.com</a></p>\n',
#   'company_logo': 'https://jobs.github.com/rails/active_storage/blobs/eyJfcmFpbHMiOnsibWVzc2FnZSI6IkJBaHBBZ3lCIiwiZXhwIjpudWxsLCJwdXIiOiJibG9iX2lkIn19--cad1cc7b3f07a5113f1eb281cf80d4c95ba80244/analyticsfire-logo.png'},
#  {'id': '99dca2ab-5151-4d67-b9d7-3c698a099e74',
#   'type': 'Full Time',
#   'url': 'https://jobs.github.com/positions/99dca2ab-5151-4d67-b9d7-3c698a099e74',
#   'created_at': 'Thu Oct 03 01:50:34 UTC 2019',
#   'company': 'LINE Fukuoka',
#   'company_url': 'https://linefukuoka.co.jp/en/career/',
#   'location': 'Fukuoka, Japan',
#   'title': 'Development Engineer (iOS/Android)',
#   'description': '<p>*<strong>Please apply to only one position at a time.</strong></p>\n<p><strong>Both Japanese and Non-Japanese speakers welcomed;</strong> Whilst there are many English speakers at LINE successful applicants may be asked to attend a Japanese training course for at least 3 ~ 12 months after joining. The training is paid for by us, and is an excellent chance to pick up new language skills. We encourage employees to reach JLPT N2 within a few years of joining.</p>\n<p>LINE is a diverse company with some of the best engineers from around the world, approximately 30% of our developers come from outside of Japan. We are looking for experienced engineers with an interest in customer focused development who wish to make an impact on our tens of millions of daily users!</p>\n<p><strong>Job Description:</strong></p>\n<p>Projects will be assigned based on our assessment of your experience taking into account your interests and career preferences.</p>\n<p><strong>【Client Development】</strong></p>\n<p>You will be involved with the development of, and operational work for, the LINE client and LINE Family App clients.</p>\n<p><strong>【Specific Responsibilities Include】</strong></p>\n<ul>\n<li>Collaborating with the Planning and Design teams to bring ideas to life (e.g. through coding, creating unit tests, etc.)</li>\n<li>Performing app profiling and improving performance</li>\n<li>Improving and maintaining a CI environment that supports stable development Improving code quality through code reviews</li>\n<li>UI/UX improvement</li>\n</ul>\n<p><strong>Examples of Client Development Work</strong></p>\n<ul>\n<li>Development of sticker/theme/emoji features in the LINE app</li>\n<li>Development of LINE Family Apps (e.g. “LINE Creators Studio”)</li>\n</ul>\n<p><strong>Required Skills:</strong></p>\n<p>Either of:</p>\n<ul>\n<li>Experienced in iOS native application development using Swift/Objective-C (3+ years).</li>\n<li>Experienced in Android native application development using Kotlin/Java (3+ years).</li>\n</ul>\n<p>And</p>\n<ul>\n<li>Professional knowledge of at least one programming language</li>\n<li>Basic knowledge in computer science (e.g. algorithm, data structure, asynchronous I/O, network)</li>\n<li>Work experience using version control systems (VCS), dependency management systems, and continuous-integration systems (CI)</li>\n<li>Communication ability in Japanese or English</li>\n<li>Motivation to learn Japanese</li>\n</ul>\n<p><strong>Preferred Skills:</strong></p>\n<ul>\n<li>Web/Native hybrid applications</li>\n<li>UI/UX design and implementation (e.g. custom views and interactions)</li>\n<li>Experience in the coaching, management and/or leadership of a technical team</li>\n<li>Open-source software development experience and/or participation in open source communities is also a plus</li>\n<li>Strong interest and ability to learn any new technical topic</li>\n</ul>\n<p><strong>Working Hours:</strong>\nDiscretionary and flexible according to ability and speed of work; if projects are completed on time there is no need to stay in the office for extended periods of time.</p>\n<p><strong>Salary:</strong></p>\n<p>Minimum salary starting from 6 million Japanese yen per annum (salary based on experience and ability).</p>\n<p>*Other details to be discussed during the interview process.</p>\n',
#   'how_to_apply': '<p>Please apply from:\n<a href="https://linefukuoka.co.jp/en/career/list/engineer/development_engineer_client-side">https://linefukuoka.co.jp/en/career/list/engineer/development_engineer_client-side</a></p>\n',
#   'company_logo': 'https://jobs.github.com/rails/active_storage/blobs/eyJfcmFpbHMiOnsibWVzc2FnZSI6IkJBaHBBdVp6IiwiZXhwIjpudWxsLCJwdXIiOiJibG9iX2lkIn19--020995eafa0bf64111f7cd8b328336dfa65d24e4/LINE_Text_Logo_TypeA.png'},
#  {'id': '1dd6197b-b2be-40bf-a1f2-5e22039e0e81',
#   'type': 'Full Time',
#   'url': 'https://jobs.github.com/positions/1dd6197b-b2be-40bf-a1f2-5e22039e0e81',
#   'created_at': 'Wed Oct 02 07:49:33 UTC 2019',
#   'company': 'LINE Fukuoka',
#   'company_url': 'https://linefukuoka.co.jp/en/career/engineer',
#   'location': 'Fukuoka, Japan',
#   'title': 'Development Engineer (Server-side) , (English and Japanese speakers welcome)',
#   'description': '<p>*<strong>Please apply to only one position at a time.</strong></p>\n<p>LINE is a diverse company with some of the best engineers from around the world, approximately 30% of our developers come from outside of Japan. We are looking for experienced engineers with an interest in customer focused development who wish to make an impact on our tens of millions of daily users!</p>\n<p><strong>Job Description:</strong></p>\n<p>We will assign the project to you after inquiring about your experience as an engineer and future career preferences.</p>\n<p><strong>【Server Development】</strong></p>\n<p>You will be operating and performing API/web application development work for server-side features of LINE’s services.</p>\n<p><strong>【Specific Responsibilities Include】</strong></p>\n<ul>\n<li>Design, develop, test, deploy, maintain and improve server-side software</li>\n<li>Contribute to architectural designs which can improve the efficiency and flexibility of our services</li>\n<li>Mentor and train team members on software design and coding standards</li>\n<li>Work closely with other teams on the development of end-user facing web applications.</li>\n<li>Support the development of high-quality code through active participation in code and design reviews</li>\n</ul>\n<p><strong>Examples of Server Development Work</strong></p>\n<ul>\n<li>Development and operation of services which support the sale and delivery of paid content such as Stickers, Emoji and Themes</li>\n<li>Service development for LINE Family Apps (e.g. “LINE Creators Market”, “LINE Fortune”, “LINE Surveys”, “LINE Part Time Jobs”, "LINE Financial" etc.)</li>\n</ul>\n<p><strong>【Tech Stack】</strong></p>\n<p>Java, Kotlin, Perl, JavaScript, Thrift, Spring Framework, MySQL, MongoDB, Redis, Kafka, Elasticsearch, Prometheus, Grafana, etc.</p>\n<p><strong>Required Skills:</strong></p>\n<ul>\n<li>Professional knowledge of at least one programming language \u3000</li>\n<li>3+ years of experience in software development, including coding experience for web services</li>\n<li>Basic knowledge in computer science (e.g. algorithm, data structure, asynchronous I/O, database, network)</li>\n<li>Work experience using version control systems (VCS), dependency management systems, and continuous-integration systems (CI)</li>\n<li>Motivation to learn Japanese</li>\n<li>Whilst there are many English speakers at LINE successful applicants may be asked to attend a Japanese training course for at least 3 ~ 12 months after joining. The training is paid for by us, and is an excellent chance to pick up new language skills.</li>\n</ul>\n<p><strong>Preferred Skills:</strong></p>\n<ul>\n<li>Experience in developing applications using Java 8+</li>\n<li>System architecture and design experience</li>\n<li>Basic knowledge of client-side technologies such as HTML, CSS and JavaScript</li>\n<li>Experience in using a Linux development environment</li>\n<li>Experience in the coaching, management and/or leadership of a technical team</li>\n<li>Open-source software development experience and/or participation in open source communities is also a plus</li>\n<li>Strong interest and ability to learn any new technical topic</li>\n<li>Communication ability in English and conversational level of Japanese (JLPT N2 or above)</li>\n</ul>\n<p><strong>Working Hours:</strong>\nDiscretionary and flexible according to ability and speed of work; if projects are completed on time there is no need to stay in the office for extended periods of time.</p>\n<p><strong>Salary:</strong>\nMinimum salary starting from 6 million Japanese yen per annum (salary based on experience and ability).</p>\n<p>*Other details to be discussed during the interview process.</p>\n',
#   'how_to_apply': '<p>Please apply from the link below:\n<a href="https://linefukuoka.co.jp/en/career/list/engineer/development_engineer_server-side">https://linefukuoka.co.jp/en/career/list/engineer/development_engineer_server-side</a></p>\n',
#   'company_logo': 'https://jobs.github.com/rails/active_storage/blobs/eyJfcmFpbHMiOnsibWVzc2FnZSI6IkJBaHBBdHh6IiwiZXhwIjpudWxsLCJwdXIiOiJibG9iX2lkIn19--41c325e1eb9651fcc7bf2f876f3c86da93051d32/LINE_Text_Logo_TypeA.png'},
#  {'id': '446a41e8-a9bd-4ad7-b7f0-40142f5a510d',
#   'type': 'Full Time',
#   'url': 'https://jobs.github.com/positions/446a41e8-a9bd-4ad7-b7f0-40142f5a510d',
#   'created_at': 'Mon Mar 23 08:26:40 UTC 2020',
#   'company': 'Smartjobr',
#   'company_url': 'https://smartjobr.com/',
#   'location': 'Hannover / Remote',
#   'title': 'Lead Backend Entwickler (w/m/d) ',
#   'description': '<p>Smartjobr ist ein agiles HR-Tech-Startup und vernetzt Freelancer aus der Kreativ- und Digitalbranche weltweit mit Auftraggebern. Dabei nutzen wir u.a. innovative Technologien (Matching und machine learning), sind mobile first (iOS + Android) im Juli 2017 an den Start gegangen und konnten mehrere tausend User aus mehr als 40 Ländern für unsere Lösung begeistern. Zur weiteren Verstärkung unseres Teams suchen wir zum nächstmöglichen Zeitpunkt einen Lead Backend Engineer (w/m/d) in Vollzeit und unbefristet, der/die große Lust hat, die Entwicklung das weitere Wachstum mit uns zu gestalten.</p>\n<p>Du kannst remote vom home office arbeiten. Das Team trifft sich 4 x im Monat, am Standort Hannover für den persönlichen Austausch.</p>\n<p><strong>Aufgaben</strong></p>\n<ul>\n<li>Enge Zusammenarbeit mit unserem CTO sowie dem Rest des bereits bestehenden Development-Teams (=&gt; aktuell 7 Leute)</li>\n<li>Teamführung und Leadfunktion</li>\n<li>Hands-on Backend-Programmierung</li>\n<li>Verantwortung für das Backend aller Plattformen</li>\n<li>Weiterentwicklung der Softwarearchitektur sowie der cloudbasierten Backend-Struktur (AWS)</li>\n<li>Optimierung der Datenbank-Systeme (PostgreSQL-Erfahrung von Vorteil)</li>\n<li>Entwicklung von internen und externen Services und Tools</li>\n<li>Data-Modeling</li>\n<li>Clean Code, Clean Architecture</li>\n</ul>\n<p><strong>Qualifikation</strong></p>\n<ul>\n<li>Absolviertes Studium (Bachelor/Master) oder eine vergleichbare Ausbildung</li>\n<li>Führungserfahrung</li>\n<li>Umfangreiche Kenntnisse in der Softwarentwicklung komplexer Anwendungen</li>\n<li>Programmierkenntnisse mit Fokus auf Python</li>\n<li>Erfahrungen mit SQL (PostgreSQL)</li>\n<li>Erfahrungen mit Machine Learning</li>\n<li>Erfahrungen mit AWS (Amazon Web Services) wären ein großer Pluspunkt, aber kein Muss</li>\n<li>Qualitätssicherung</li>\n<li>Hohe Lernbereitschaft, lösungsorientiertes Denken und Handeln</li>\n<li>Gute bis sehr gute Englischkenntnisse</li>\n</ul>\n<p><strong>Benefits</strong></p>\n<ul>\n<li>Ein spannendes Produkt mit globalem Potenzial und viel Aufbauarbeit</li>\n<li>Ein hochmotiviertes, interdisziplinäres Team mit moderner Arbeitsweise</li>\n<li>Agiles Arbeiten, Lean-Startup-Kultur, äußerst flexible Arbeitszeiten, E-Mail freie Kommunikation, Home Office und Remote</li>\n</ul>\n<p>Wenn du dich hiervon angesprochen fühlst, dann freuen wir uns auf deine schlanken Bewerbungsunterlagen (CV oder Link zu einer Website, GitHub oder Social Media Profilen reicht oder telefonisch unter 0511 99979544).</p>\n',
#   'how_to_apply': '<p><a href="https://smartjobr.join.com/jobs/798865-lead-backend-entwickler-w-m-d-remote?pid=357a3b4531918760973f&amp;utm_source=github_jobs&amp;utm_medium=paid&amp;utm_campaign=single%2Bposting&amp;utm_content=lead%2Bbackend%2Bentwickler%2Bw%2Bm%2Bd%2Bremote">https://smartjobr.join.com/jobs/798865-lead-backend-entwickler-w-m-d-remote?pid=357a3b4531918760973f&amp;utm_source=github_jobs&amp;utm_medium=paid&amp;utm_campaign=single%2Bposting&amp;utm_content=lead%2Bbackend%2Bentwickler%2Bw%2Bm%2Bd%2Bremote</a></p>\n',
#   'company_logo': 'https://jobs.github.com/rails/active_storage/blobs/eyJfcmFpbHMiOnsibWVzc2FnZSI6IkJBaHBBZ21CIiwiZXhwIjpudWxsLCJwdXIiOiJibG9iX2lkIn19--fbec4603c841324051e90a46642eca00d72b6efe/Smartjobr-1200x1200.jpg'},
#  {'id': '7a945587-78c0-4abf-9d8e-c0b6f8078c54',
#   'type': 'Full Time',
#   'url': 'https://jobs.github.com/positions/7a945587-78c0-4abf-9d8e-c0b6f8078c54',
#   'created_at': 'Fri Mar 20 14:51:58 UTC 2020',
#   'company': 'CompuGroup Medical',
#   'company_url': 'https://www.cgm.com/nl/index.nl.jsp',
#   'location': 'Echt',
#   'title': 'DevOps Engineer',
#   'description': '<h2>Als DevOps Engineer maak je nu reeds deel uit van onze toekomst!</h2>\n<p>Als een pionier binnen de digitale gezondheidszorg hechten we belang aan het ontwikkelen en implementeren van nieuwe technologieën. Voor de volgende generatie van eHealth-evolutie zijn we op zoek naar creatieve geesten die energie halen uit het werken met een verscheidenheid aan technologieën, aan de hand van hun eigen ontwerpvrijheid en professionele ontwikkeling.</p>\n<h2>Draag bij aan ons succes:</h2>\n<p>\xa0</p>\n<h2>Afdeling:</h2>\n<p>De Technisch Applicatiebeheerder zorgt ervoor dat applicaties in technisch complexe omgevingen toch perfect blijven draaien. In de huidige online wereld waarin veel applicaties altijd, overal en tegelijk worden gebruikt, is de technisch applicatiebeheerder een specialist die zowel de applicatie als de onderliggende infrastructuur doorgrondt. Dat maakt hem soms letterlijk ‘mission-critical’ voor zijn omgeving. Je bent communicatief sterk en hebt een groot empathisch vermogen om verbeteringen aan te dragen bij verschillende eigenaars van applicaties. Je zal binnen deze functie in een groter team opereren maar bent zelf verantwoordelijk voor deze rol. Met jouw kennis en pro actieve drive maak je het landschap groter en innoveert waar nodig.</p>\n<p>De applicaties draaien onder andere op:</p>\n<ul>\n<li>De hosting van je organisatie</li>\n<li>Servers op locatie van de klant, maar beheerd door jouw organisatie</li>\n<li>Servers bij hosting partijen, die niet worden beheerd door jouw organisatie, maar de applicaties wel</li>\n<li>De applicaties draaien op Windows en SQL server</li>\n<li>De applicaties zijn ontwikkeld in .NET, voornamelijk C#. Er wordt tevens gewerkt met Angular</li>\n<li>Er is sprake van zowel Web applicaties als client server applicaties. Het laatste wordt middels een terminal server oplossing aan klant geleverd</li>\n</ul>\n<h2>Functie:</h2>\n<ul>\n<li>Begeleiden en uitvoeren van wijzigingen aan bestaande ICT-systemen. Het maken van impactanalyses en bijdragen aan het besluitproces is hier eveneens onderdeel van;</li>\n<li>Leveren van een bijdrage aan het versiebeheer, configuratiebeheer en licentiebeheer;</li>\n<li>Als spin-in-het-web samenwerken met functioneel beheer, infrastructuur beheer, databasebeheer en applicatie-eigenaar;</li>\n<li>Nieuwe applicaties zo efficiënt mogelijk onboarden in het dashboard</li>\n<li>Monitoren van de prestaties van applicaties;</li>\n<li>Proactief actie(s) ondernemen met betrekking tot verbeteringen en stabiliteit van de applicatie(s);</li>\n<li>Opstellen en onderhouden van technische- en beheerdocumentatie;</li>\n<li>Opstellen van (SLA) maandrapportages;</li>\n</ul>\n<h2>Wat wij verwachten:</h2>\n<ul>\n<li>Kennis van Linux</li>\n<li>Kennis van Containers (Docker, Kubernetes)</li>\n<li>Apache Kafka is een pré</li>\n<li>Kennis van Ansible</li>\n<li>Een scripting taal zoals Python</li>\n<li>DevOps way of working</li>\n<li>HBO of WO werk- en denkniveau</li>\n<li>Je beheerst de Engelse taal in woord en geschrift</li>\n<li>Analytisch sterk, pro-actieve instelling, teamspeler</li>\n</ul>\n<h2>Wat wij jou te bieden hebben:</h2>\n<ul>\n<li>Een afwisselende en verantwoordelijke baan binnen een enthousiast en\nprofessioneel team in een modern en snelgroeiend bedrijf</li>\n<li>Een aantrekkelijk salaris</li>\n<li>Pensioenvergoeding</li>\n<li>25 vakantiedagen</li>\n<li>Incidenteel thuiswerken</li>\n<li>Reiskostenvergoeding (€0,19 per km of 100% OV)</li>\n<li>Laptop van de zaak</li>\n</ul>\n<p>Indien je belangstelling hebt voor de functie en voldoet aan het gevraagde profiel en de functie-eisen, dan ontvangen we graag je sollicitatie via het sollicitatieformulier.</p>\n<p><a href="https://compugroupmedical.redirect.your-jobresponse.com/devops_engineer_echt/266025/V819/apply">Klik hier voor het sollicitatieformulier!</a></p>\n<h2>Synchronizing Healthcare</h2>\n<p>\xa0</p>\n<h2>Be part of it now!</h2>\n<p>Referentie nummer:</p>\n<p><strong>req3634</strong></p>\n<p> ...
#   'how_to_apply': '<p><a href="https://compugroupmedical.redirect.your-jobresponse.com/devops_engineer_echt/266025/V819/apply">Klik hier voor het sollicitatieformulier!</a></p>\n',
#   'company_logo': 'https://jobs.github.com/rails/active_storage/blobs/eyJfcmFpbHMiOnsibWVzc2FnZSI6IkJBaHBBZ2VCIiwiZXhwIjpudWxsLCJwdXIiOiJibG9iX2lkIn19--54edd05e88c8600fc6ab1b341bbcb18125698f5d/Compugroup.jpg'},
#  {'id': 'eb7267e7-9a5d-48ad-a2c3-8fca50aeeece',
#   'type': 'Full Time',
#   'url': 'https://jobs.github.com/positions/eb7267e7-9a5d-48ad-a2c3-8fca50aeeece',
#   'created_at': 'Fri Mar 20 14:08:12 UTC 2020',
#   'company': 'moovel Group GmbH (REACH NOW)',
#   'company_url': 'https://www.moovel.com/de/DE',
#   'location': 'Berlin',
#   'title': 'Software Engineer (d/f/m) for Place Search Squad',
#   'description': '<h2>Hi,</h2>\n<p>we are the place search squad at moovel, and we work on the place search engine used by all moovel apps. Users engage with place search as the first step of their transit journey. Our job is to help them find what they are looking for with the least amount of effort on their part. Specifically, if a user types a bunch of characters into a search field, we analyze their input using textual analysis, user and place contexts, distance, popularity, etc, in order to have their intended location displayed at the first rank. This is no easy task and is perhaps the reason why most companies opt for an off the shelf SaaS offering to provide a place search. We dislike black boxes and find these kinds of challenges exciting! This also gives us the freedom to innovate and develop a highly integrated and specialized search experience for our use cases.</p>\n<h2>First a quick look at us</h2>\n<p>The topic of mobility is evolving at a startling pace. Fundamentals are being questioned, new ways of getting around are emerging and challenging the established ones. At Moovel (becomes REACH NOW), we aim to take part in shaping that future. Software is eating the world and mobility is certainly no exception. Ultimately, we want to help cities become smarter by building on the operational wisdom of city administrations and mobility service providers. We don’t want to disrupt but augment the means of getting around by employing contemporary technologies.</p>\n<p>The problems we are engaging in are manifold and from the real world. Our solutions do not only have an impact on a single industry branch but also aim to transform the city. They involve fields like routing, searching, AI, innovative UX and much more. Things are very dynamic in the mobility space and thus we devote ourselves to a lot of exploratory work.</p>\n<h2>About the team</h2>\n<p>The place search squad is a small engineering team dedicated to place search. We enjoy a high degree of autonomy, trust and responsibility. We value pragmatism, simplicity and collaboration. We have an open feedback and failure culture, because we know that both are necessary to find proper solutions. We embrace agile in a non-dogmatic fashion.</p>\n<p>Teams at moovel choose the tools they regard as the best fit for their problems, at their discretion. Hence the technology stack is rather diverse. We employ a microservice backend architecture based on Docker and AWS. Cloud Services are leveraged wherever they help us to focus on our task. We practice continuous delivery and value DevOps culture (you build it, you run it).</p>\n<h2>Some of the things you will do</h2>\n<p>Research and optimize search results using information retrieval tools such as Elasticsearch and methods such as natural language processing (NLP), learning to rank (LTR), and Bayesian hyperparameter optimization (HPO).</p>\n<ul>\n<li>Build large-scale microservices and product integrations.</li>\n<li>Work on our data import pipeline.</li>\n<li>Assess and remedy search and data quality issues.</li>\n<li>Discover insights through exploratory data analysis to improve search performance.</li>\n<li>Develop new ways to learn from our real-world users.</li>\n<li>Develop a machine learning infrastructure and platform.</li>\n</ul>\n<h2>Your skill set</h2>\n<ul>\n<li>Experience in Node.js, Python, or similar stacks.</li>\n<li>Experience with information retrieval, ranking systems, recommendation systems or artificial intelligence.</li>\n<li>Familiarity with Lucene and Elasticsearch / Solr.</li>\n<li>Familiarity with AWS or other cloud technologies.</li>\n<li>Fluency in Business English is mandatory.</li>\n</ul>\n<h2>Benefits</h2>\n<ul>\n<li>Choose your own hardware</li>\n<li>Working with newest technologies &amp; microservices</li>\n<li>Be part of an interdisciplinary team of experts</li>\n<li>Working on products with a high impact on society</li>\n<li>International teams</li>\n<li>Flexible working hours</li>\n<li>We ...
#   'how_to_apply': '<p><a href="https://moovelgroup.redirect.your-jobresponse.com/software_engineer_d_f_m_for_place_search_squad_berlin/266023/V819/anwenden">Click here for the application form!</a></p>\n',
#   'company_logo': 'https://jobs.github.com/rails/active_storage/blobs/eyJfcmFpbHMiOnsibWVzc2FnZSI6IkJBaHBBZ1dCIiwiZXhwIjpudWxsLCJwdXIiOiJibG9iX2lkIn19--34b62890786476dec3e88330ee5d754c147e389f/moovel%20reachnow.jpg'},
#  {'id': '08070f4f-3b01-4143-b80c-a539e7eeb57c',
#   'type': 'Full Time',
#   'url': 'https://jobs.github.com/positions/08070f4f-3b01-4143-b80c-a539e7eeb57c',
#   'created_at': 'Fri Mar 20 09:18:23 UTC 2020',
#   'company': 'Smartjobr\t',
#   'company_url': 'https://smartjobr.com/',
#   'location': 'Hannover/ Remote',
#   'title': 'CTO (w/m/d) (Remote)',
#   'description': '<p>Smartjobr ist ein agiles HR-Tech-Startup und vernetzt Freelancer aus der Kreativ- und Digitalbranche weltweit mit Auftraggebern. Dabei nutzen wir Machine Learning, sind Mobile First (iOS + Android) im Juli 2017 an den Start gegangen und konnten mehrere tausend User aus mehr als 40 Ländern für unsere Lösung begeistern. Zur weiteren Verstärkung unseres Teams suchen wir zum nächstmöglichen Zeitpunkt einen CTO (w/m/d) in Vollzeit und unbefristet mit großer Lust, die Entwicklung des weiteren Wachstums mit uns zu gestalten.</p>\n<p>Hier ist remote möglich und home office für uns normal. Das Team trifft sich 4 x im Monat am Standort Hannover.</p>\n<p><strong>Aufgaben</strong></p>\n<ul>\n<li>Verantwortung aller Aktivitäten im Unternehmensbereich Technology</li>\n<li>Gestaltung unserer zukunftsorientierten Technologie-Roadmap</li>\n<li>Verantwortlich für die Weiterentwicklung der Infrastruktur, Anwendungssysteme und dessen reibungslosem Betrieb</li>\n<li>Enge Kooperation mit der Geschäftsführung und aktive Unterstützung bei der Unternehmensentwicklung</li>\n<li>Verantwortlich für die Motivation, Entwicklung und den Aufbau des Teams</li>\n</ul>\n<p><strong>Qualifikation</strong></p>\n<ul>\n<li>Absolviertes Studium (Bachelor/Master) oder eine vergleichbare Ausbildung</li>\n<li>Führungserfahrung</li>\n<li>Umfangreiche Kenntnisse in der agilen Software- und Projektplanung komplexer Anwendungen</li>\n<li>Erfahrungen mit AWS (Amazon Web Services) wären ein großer Pluspunkt</li>\n<li>Hohe Lernbereitschaft, lösungsorientiertes Denken und Handeln</li>\n<li>Gute bis sehr gute Englischkenntnisse</li>\n</ul>\n<p><strong>Benefits</strong></p>\n<ul>\n<li>Ein spannendes Produkt mit globalem Potenzial und viel Aufbauarbeit</li>\n<li>Ein hochmotiviertes, interdisziplinäres Team mit moderner Arbeitsweise</li>\n<li>Agiles Arbeiten, Lean-Startup-Kultur, äußerst flexible Arbeitszeiten, E-Mail freie Kommunikation, Home Office und Remote</li>\n</ul>\n<p>Wenn du dich hiervon angesprochen fühlst, dann freuen wir uns auf deine schlanken Bewerbungsunterlagen (CV oder Link zu einer Website, GitHub oder Social Media Profilen reicht oder telefonisch unter 0511 99979544).</p>\n',
#   'how_to_apply': '<p><a href="https://smartjobr.join.com/jobs/822977-cto-w-m-d-remote?pid=357a3b4531918760973f&amp;utm_source=github_jobs&amp;utm_medium=paid&amp;utm_campaign=single%2Bposting&amp;utm_content=cto%2Bw%2Bm%2Bd%2Bremote">https://smartjobr.join.com/jobs/822977-cto-w-m-d-remote?pid=357a3b4531918760973f&amp;utm_source=github_jobs&amp;utm_medium=paid&amp;utm_campaign=single%2Bposting&amp;utm_content=cto%2Bw%2Bm%2Bd%2Bremote</a></p>\n',
#   'company_logo': 'https://jobs.github.com/rails/active_storage/blobs/eyJfcmFpbHMiOnsibWVzc2FnZSI6IkJBaHBBZ0tCIiwiZXhwIjpudWxsLCJwdXIiOiJibG9iX2lkIn19--c0544708b1630e0c2bde1904343d76c10779aee4/Smartjobr-1200x1200.jpg'},
#  {'id': 'f1726140-ded0-4468-8593-705256d04c93',
#   'type': 'Full Time',
#   'url': 'https://jobs.github.com/positions/f1726140-ded0-4468-8593-705256d04c93',
#   'created_at': 'Fri Mar 20 09:02:23 UTC 2020',
#   'company': 'BWI GmbH',
#   'company_url': 'http://www.bwi-it.de',
#   'location': 'Rheinbach, München',
#   'title': 'Fachinformatiker für Systemintegration / IT Systemadministrator (m/w/d) Schwerpunkt Application & Device Control (ADC) ',
#   'description': '<h2>Sorgen Sie gemeinsam mit uns für die digitale Zukunftsfähigkeit unseres Landes.</h2>\n<p>Als IT-Partner der Bundeswehr und IT-Dienstleistungszentrum des Bundes bieten wir umfassende IT-Services aus einer Hand. Mit über 4.800 Mitarbeiterinnen und Mitarbeitern zählen wir zu den zehn größten IT-Service-Providern Deutschlands. Wir suchen authentische IT-Liebhaberinnen und IT-Liebhaber, die ihre Leidenschaft mit uns teilen wollen, auf der Suche nach anspruchsvollen IT-Herausforderungen sind und Deutschlands IT gestalten möchten.</p>\n<p>Unser Department für Workplace Security der Central Operations verantwortet den Betrieb der durch die BWI GmbH angebotenen Security Services. Unter anderem fällt ein derzeit in der Entwicklung befindlicher Service für Application &amp; Device Control (Application Whitelisting) in unseren Aufgabenbereich. Verstärken Sie unser bestehendes Team als Experte für Application &amp; Device Control (ADC) (m/w/d).</p>\n<h2>Ihre Aufgaben:</h2>\n<ul>\n<li>SLA-konformer Betrieb des Services</li>\n<li>Betriebliche Umsetzung eines ITIL-konformen Incident-, Problem- und Change Management-Prozesses</li>\n<li>Qualitätsgesicherte Übernahme von erarbeiteten Lösungen in die Produktion in enger Abstimmung mit allen betroffenen Einheiten</li>\n<li>Erstellung und Aktualisierung von Einträgen im Knowledge Management sowie von operativen Dokumentationen</li>\n<li>Unterstützung des Problem Managements sowie des 3rd Level Supports bei Fehleranalysen</li>\n<li>Zusammenarbeit mit Architektur- und Produktverantwortlichen zur Berücksichtigung betrieblicher Aspekte</li>\n</ul>\n<h2>Ihr Profil:</h2>\n<ul>\n<li>Eine abgeschlossene Ausbildung zum Fachinformatiker für Systemintegration oder eine vergleichbare Qualifikation</li>\n<li>Mindestens 3 Jahre einschlägige Berufserfahrung</li>\n<li>Fachwissen in einem oder mehreren der folgenden Bereiche: Client &amp; Server-Architektur, Active Directory, Firewall und Netzwerk Topologie sowie Datenbanken im</li>\n<li>Umfeld der Microsoft Plattformen</li>\n<li>Idealerweise gute Kenntnisse in der Automatisierung mittels Scriptsprachen (z.B. Powershell) oder Programmiersprachen (z.B. C#)</li>\n<li>Eine ITIL v3 Foundation-Zertifizierung ist wünschenswert</li>\n<li>Verhandlungssichere Deutsch- sowie technische Englischkenntnisse in Wort und Schrift</li>\n</ul>\n<h2>Wir bieten:</h2>\n<ul>\n<li>Spannende und abwechslungsreiche Aufgaben in einem innovativen und bedeutsamen Umfeld</li>\n<li>Vielfältige interne und externe Weiterbildungsmöglichkeiten sowie individuelle Karrieremodelle</li>\n<li>Coaching-Angebote und Möglichkeiten zur Persönlichkeitsentwicklung in einer wertschätzenden Arbeitsatmosphäre</li>\n<li>Gratis Fitnessstudio-Mitgliedschaft über Urban Sports Club und weitere attraktive Mitarbeitervergünstigungen</li>\n<li>Vertrauensarbeitszeit. Je nach Aufgabenfeld sind mobiles Arbeiten und flexible Arbeitszeitmodelle möglich</li>\n<li>Ein attraktives Vergütungspaket inkl. arbeitgeberfinanzierter betrieblicher Altersvorsorge</li>\n</ul>\n<h2>Haben wir Ihr Interesse geweckt?</h2>\n<p>Dann bewerben Sie sich über das <strong>Bewerbungsformular</strong></p>\n<p>Unser Recruitingteam</p>\n<h2>Sie haben Fragen?</h2>\n<p>Schreiben Sie uns an <a href="mailto:bewerbung@bwi.de">bewerbung@bwi.de</a>.</p>\n<p>Oder rufen Sie an: +49 (0)2225 988 3990</p>\n<p><a href="https://bwi-it.redirect.your-jobresponse.com/fachinformatiker_als_experte_fuer_application_device_control_adc_m_w_d_rheinbach/265893/V819/anwenden">Klicken Sie hier um zum Bewerbungsformular zu gelangen!</a></p>\n',
#   'how_to_apply': '<p><a href="https://bwi-it.redirect.your-jobresponse.com/fachinformatiker_als_experte_fuer_application_device_control_adc_m_w_d_rheinbach/265893/V819/anwenden">Klicken Sie hier um zum Bewerbungsformular zu gelangen!</a></p>\n',
#   'company_logo': 'https://jobs.github.com/rails/active_storage/blobs/eyJfcmFpbHMiOnsibWVzc2FnZSI6IkJBaHBBZ0NCIiwiZXhwIjpudWxsLCJwdXIiOiJibG9iX2lkIn19--30150d86ff5040a9d0ba4f2e8f468bb2d97531cc/BWI.jpg'},
#  {'id': '051f00e9-068c-47b8-a85a-674a626eff17',
#   'type': 'Full Time',
#   'url': 'https://jobs.github.com/positions/051f00e9-068c-47b8-a85a-674a626eff17',
#   'created_at': 'Thu Mar 19 17:57:51 UTC 2020',
#   'company': 'Gorgias',
#   'company_url': 'https://www.gorgias.com/',
#   'location': 'Paris and San Francisco',
#   'title': 'Full-Stack Engineer',
#   'description': '<p>We created the company in Paris and are now a San Francisco based startup with a newly opened Paris office. We\'re making a SaaS helpdesk that automates a big part of the repetitive customer support tasks. We\'re close to 2000+ paying companies using our product and growing fast. We’re looking to expand our team and make our product even better!</p>\n<p>If this spiked your interest here’s a bit more info about our stack and how we work at Gorgias:\nThe backend code is mostly written in Python and runs using Flask (REST API) and Celery for all background work. The state is stored in PostgreSQL and RabbitMQ with Redis for ephemeral storage, and finally, everything runs on Kubernetes.</p>\n<p>We have a strong preference for people who worked with high-traffic web applications for the past 3+ years. We\'re essentially running a distributed system that has lots of moving parts and having a decent amount of experience with this type of system helps a lot!</p>\n<p>Additionally, our apps have over 5000 daily active users with sessions longer than 6h/day and tens of millions of end consumers per year. That is why we put great importance on quality, testing, and code-review of all our code. Our apps have big codebases, and we have to feel comfortable about navigating and progressively improving them. Sometimes, however, we gotta get dirty and figure out why the DB is slow or why some k8s pod is not running correctly, figure out how to successfully retry a failing API request, etc…</p>\n<p><em>We have two openings available, one for both offices: Paris (France) and San Francisco (USA).</em></p>\n<p><strong>What You’ll Do</strong></p>\n<ul>\n<li>Making our React and React Native applications gorgeous and progressively improving them</li>\n<li>Scaling and maintaining our chat application that serves millions of concurrent users</li>\n<li>Fixing bugs, updating/refactoring the existing apps</li>\n<li>There\'s still lots of stuff to improve</li>\n<li>And more…</li>\n</ul>\n<p><strong>About You</strong></p>\n<ul>\n<li>1+ years of experience developing web applications</li>\n<li>3+ years of experience doing back-end development with Python</li>\n<li>3+ years of experience doing front-end development with JavaScript</li>\n<li>You are eager to solve unique e-commerce problems</li>\n<li>You are passionate about learning, and want to help us learn too</li>\n<li>You care about working on applications that are putting the customer needs first</li>\n<li>You are comfortable communicating with other technical teams and management to collect requirements, describe software product features, demo work in progress and provide project updates</li>\n<li>You have the drive and focus to get challenging projects over the finish line, and you are comfortable advocating for what you need to do your best work</li>\n<li>You thrive in a fast-paced environment</li>\n</ul>\n<p><strong>Nice to Have</strong></p>\n<ul>\n<li>Experience in designing API/microservices is a huge plus</li>\n<li>Experience with large-scale e-commerce</li>\n<li>Experience with high-traffic web applications</li>\n<li>Experience with agile tools like GitHub</li>\n<li>Understanding of HTTP and Websockets</li>\n<li>Experience working directly with DOM, CSS</li>\n</ul>\n<p><strong>Company Perks &amp; Benefits</strong></p>\n<ul>\n<li>Competitive salary, equity packages and performance bonus packages</li>\n<li>4 weeks vacation and parental leave</li>\n<li>Latest MacBook Pro or equivalent</li>\n<li>Natural sunlight and open office with lounge area</li>\n<li>Walking distance from Bart (6-10 minutes)</li>\n<li>Visa sponsorship and relocation expenses</li>\n<li>Catered lunch 5x per week (rooftop access)</li>\n<li>Retirement benefits</li>\n<li>Unlimited snacks</li>\n<li>Health coverage</li>\n</ul>\n<p><strong>Useful Things to Know About Gorgias</strong></p>\n<ul>\n<li><a href="techcrunch.com/2019/11/26/gorgias-series-a">Raised our Series A in November</a></li>\n<li><a href="apps.shopif ...
#   'how_to_apply': '<p><a href="https://jobs.lever.co/gorgias">https://jobs.lever.co/gorgias</a></p>\n',
#   'company_logo': 'https://jobs.github.com/rails/active_storage/blobs/eyJfcmFpbHMiOnsibWVzc2FnZSI6IkJBaHBBdnlBIiwiZXhwIjpudWxsLCJwdXIiOiJibG9iX2lkIn19--399af4ca237d876a5940f0d029ae953e2132adc1/5c6efb258a6fd87edf75b038_Gorgias%20web.jpg'},
#  {'id': '26782570-f098-4e2b-af83-e98ba13a78e2',
#   'type': 'Full Time',
#   'url': 'https://jobs.github.com/positions/26782570-f098-4e2b-af83-e98ba13a78e2',
#   'created_at': 'Thu Mar 19 14:20:40 UTC 2020',
#   'company': 'Neonomics AS',
#   'company_url': 'http://www.neonomics.io',
#   'location': '@Oslo',
#   'title': 'Site Reliability Engineer',
#   'description': '<p><strong>Are you interested in automation and FinTech?</strong></p>\n<p><em>Fresh out of the Nordics in 2016, Neonomics (meaning “New Economy”) was founded as a direct response to the impending challenges facing the banking industry during its radical transition into the era of open banking. We are building a high-value ecosystem of fintech solutions for the next generation of financial services and today we are connected to more than 1300 banks within the EU, with the connections built on our unique API integration technology.</em></p>\n<p>We are now looking for a Site Reliability Engineer to join our Neonomics family. In this position you will work with Agile engineering teams to provide production insight into running and operating software at-scale in a globally distributed highly available cloud based system. You will guide the team to consider scale-out implications and operational support implications of the choices they make during the development cycle, and you will play a hands-on role helping the team meet ambitious technical, operational, schedule, and business requirements.</p>\n<p><strong>Responsibilities:</strong></p>\n<ul>\n<li>Aid in building and supporting a container based platform architecture that can ensure microservice teams can own their code all the way into production.</li>\n<li>Build and support tooling and automated infrastructure necessary to deliver metrics from production environments, deploy releases to production environments, and manage multiple versions of multiple microservices operating in tandem to produce a fully functional system.</li>\n<li>Work with a team of backend and application development engineers to further institutionalize the notion of the team owns their code in production and offer suggestions on how to better do that in the context of the development sprint work.</li>\n</ul>\n<p><strong>About you:</strong></p>\n<p>To succeed in this position, we believe that you are system thinker with a passion for creating products that deliver incredible customer experiences. We wish that you have experience with operational automation and data driven metrics collection, and it is important that you have a true desire to automate it rather than do it repeatedly.</p>\n<p>We also wish that you have:</p>\n<ul>\n<li>Experience running an at-scale global cloud based application in AWS or Google Cloud platforms with Docker and Kubernetes.</li>\n<li>Experience automating in Python, Ruby or rapid-development languages as well as infrastructure as code.</li>\n<li>Experience in networking protocols, IP routing issues, TLS and diagnosing routing or high-level network transactional issues through logs and metrics.\n\xa0</li>\n</ul>\n<p><strong>Why work with us?</strong></p>\n<p>Besides having the warmest, funniest and the most including colleges, we can offer the following:</p>\n<ul>\n<li>A start-up environment and mentality where your voice is important and will be heard.</li>\n<li>A flat structure with direct access to decision makers.</li>\n<li>A highly stimulating cross-functional team environment with more than 15 nationalities and plenty of opportunities for personal and professional development.</li>\n<li>Relaxed environment with informal dress code.</li>\n<li>A lot of social activities like Fintalks, dinners and Friday-beers.</li>\n<li>And of course, we offer competitive salary and benefits, ex. 7% pension benefit.\n\xa0</li>\n</ul>\n',
#   'how_to_apply': '<p><a href="https://candidate.hr-manager.net/ApplicationInit.aspx?cid=2129&amp;ProjectId=143588&amp;DepartmentId=18957&amp;MediaId=5">Apply for this position</a></p>\n',
#   'company_logo': 'https://jobs.github.com/rails/active_storage/blobs/eyJfcmFpbHMiOnsibWVzc2FnZSI6IkJBaHBBdmFBIiwiZXhwIjpudWxsLCJwdXIiOiJibG9iX2lkIn19--a78b51fac7bfc91de056c8bde89c6587e8dd6750/Neonomics_symbol_RGB.png'},
#  {'id': '0111dd85-71cd-45e3-972c-023b152005d6',
#   'type': 'Full Time',
#   'url': 'https://jobs.github.com/positions/0111dd85-71cd-45e3-972c-023b152005d6',
#   'created_at': 'Wed Mar 18 23:23:32 UTC 2020',
#   'company': 'Triplebyte',
#   'company_url': 'http://www.triplebyte.com',
#   'location': 'San Francisco or Remote',
#   'title': 'Full Stack Engineer',
# ...
#   'how_to_apply': '<p><a href="https://cbs.redirect.your-jobresponse.com/software_engineer_information_dialogue_den_haag/236455/V819/solliciteren">Klik hier om te solliciteren!</a></p>\n',
#   'company_logo': 'https://jobs.github.com/rails/active_storage/blobs/eyJfcmFpbHMiOnsibWVzc2FnZSI6IkJBaHBBdHhXIiwiZXhwIjpudWxsLCJwdXIiOiJibG9iX2lkIn19--9f323b086b0d7131427118caed32b27ccc8e4bb2/cbac23b1-3b1e-4c28-a8fc-49df1095e6ef'},
#  {'id': '18f5af34-e8c7-11e8-85f6-109da02adff9',
#   'type': 'Full Time',
#   'url': 'https://jobs.github.com/positions/18f5af34-e8c7-11e8-85f6-109da02adff9',
#   'created_at': 'Thu Nov 15 11:12:09 UTC 2018',
#   'company': 'Sterblue',
#   'company_url': 'https://www.sterblue.com',
#   'location': 'Remote Job',
#   'title': 'Lead front-end engineer',
#   'description': '<p>Lead front-end engineer\n\nJob description\nSterblue builds software for\xa0Drones\xa0to inspect Wind Turbines and Power Lines automatically using\xa0Artificial Intelligence. From automatic 3D navigation around infrastructures to online reports and automatic defect detection, we automate the entire inspection process to help energy and utility companies strive for a cleaner future.\n\nWe are looking for a Senior or Lead web front-end and mobile developer with experience in UI/UX, that will be able to help manage our team operationally and technically. At Sterblue, you will:</p>\n\n\n\n',
#   'how_to_apply': '<p>Apply here</p>\n',
#   'company_logo': 'https://jobs.github.com/rails/active_storage/blobs/eyJfcmFpbHMiOnsibWVzc2FnZSI6IkJBaHBBdGhXIiwiZXhwIjpudWxsLCJwdXIiOiJibG9iX2lkIn19--d17ed9dcb168d5f4124e2fab7b976d8f9c27947c/659f247c-8395-473d-956d-ff1c0b1ec3f6'},
#  {'id': 'd28b2d1a-e85a-11e8-9b78-62dc829f5516',
#   'type': 'Full Time',
#   'url': 'https://jobs.github.com/positions/d28b2d1a-e85a-11e8-9b78-62dc829f5516',
#   'created_at': 'Wed Nov 14 22:16:02 UTC 2018',
#   'company': 'The Atlantic',
#   'company_url': 'http://theatlantic.com',
#   'location': 'Washington, DC & New York, NY',
#   'title': 'Lead Front End Developer',
#   'description': '<p>The Atlantic is a digital-first media company with over 160 years of history and 36 million readers a month. Founded in 1857 and today one of the fastest-growing media platforms in the industry, The Atlantic has throughout its history championed the power of big ideas and continues to shape global debate through our two websites: TheAtlantic.com and CityLab.com. We work in a fast-paced, team-oriented environment out of our office in the historic Watergate complex in Washington DC. This role can be based in either Washington, DC or New York, NY.</p>\n<p><strong>Who You Are</strong></p>\n<p>You are an experienced developer with proven leadership and management experience.</p>\n<p>You are well versed in the modern front-end, and can mentor junior members of the team on the latest best practices concerning ES6, SCSS, and performance. You know how to collaborate with designers, are knowledgeable about CSS conventions and naming methodologies such as BEM, SMACSS, OOCSS, and can describe their relative merits.</p>\n<p>Your experience has taught you the architectural strategies and practices that are necessary for organizing and maintaining front end code that can scale as our team continues to grow. You know how to evaluate new technology and determine which path will best fit our business needs.</p>\n<p>Above all, you’re a creative problem solver: able to devise and deliver practical, maintainable software that addresses Atlantic staffers’ and readers’ needs.</p>\n<p><strong>Primary Responsibilities</strong>:</p>\n<ul>\n<li>Provide feedback and mentorship to the front end team through weekly one-on-one check as well as mid and end of the year reviews</li>\n<li>Help plan and execute team and individual goals, with an eye on team growth and development</li>\n<li>Champion ways to improve our front end tech stack, including tooling, unit testing, and architecture</li>\n<li>Collaborate with team members to plan projects, creating technical road maps and breaking projects up into individual tasks as necessary while always keeping in mind long term maintainability</li>\n<li>Act as a role model to others on the team by exhibiting strong work ethic and technical expertise when writing code or building new website features</li>\n<li>Act as a expert who can provide technical help and guidance to the other front end developers</li>\n</ul>\n<p><strong>Requirements</strong>:</p>\n<ul>\n<li>Proven experience with technical leadership and management</li>\n<li>Experience architecting a front end codebase at scale</li>\n<li>Strong technical and non-technical communication skills</li>\n<li>Able to look at a design and break it into well organized reusable components</li>\n<li>Experience planning, ticketing, and executing team projects</li>\n<li>Comfortable with Git for version control</li>\n<li>Effective time management when working on multiple projects</li>\n<li>Passionate about front end performance with up-to-date knowledge of current techniques</li>\n<li>Familiar with Node.js and modern frontend build tooling</li>\n<li>Knowledgeable about modern JavaScript frameworks but comfortable working in Vanilla JS</li>\n<li>Able to provide a code sample demonstrating expertise at writing and organizing CSS, HTML, and - JavaScript suitable for a complex, fast-changing website</li>\n</ul>\n<p><strong>Benefits</strong></p>\n<p>Employees at The Atlantic are entitled to benefits including: 401(k) savings plan with employer match, health care with domestic partner coverage, flexible vacation and sick leave policy, commuter benefits, and rooftop happy hours with one of the best views in DC.</p>\n<p><strong>Atlantic Media Values</strong>:</p>\n<p>Across Atlantic Media, generally, the firm looks for two “pillar gifts” in you, and everyone else.  In all of us, these are more aspirational than actual, but they are central in our intentions –</p>\n<ul>\n<li>\n<strong>Force of Ideas</strong>: At the center of Atlantic Media work are the ideas within ...
#   'how_to_apply': '<p>Apply online: <a href="https://atlanticmedia.theresumator.com/apply/b6ZvfSoePV/Lead-Front-End-Developer?source=Github">https://atlanticmedia.theresumator.com/apply/b6ZvfSoePV/Lead-Front-End-Developer?source=Github</a></p>\n',
#   'company_logo': 'https://jobs.github.com/rails/active_storage/blobs/eyJfcmFpbHMiOnsibWVzc2FnZSI6IkJBaHBBdFZXIiwiZXhwIjpudWxsLCJwdXIiOiJibG9iX2lkIn19--b5696c45ec9ba49ead9190535e55a9e2ca213021/dda99823-bc1b-4669-800b-48e3971f2d37'},
#  {'id': '0e9e93a6-e85a-11e8-8963-f68a643e24dd',
#   'type': 'Full Time',
#   'url': 'https://jobs.github.com/positions/0e9e93a6-e85a-11e8-8963-f68a643e24dd',
#   'created_at': 'Wed Nov 14 22:11:05 UTC 2018',
#   'company': 'The Atlantic',
#   'company_url': 'http://theatlantic.com',
#   'location': 'Washington, DC & New York, NY',
#   'title': 'Senior Front End Developer',
#   'description': '<p>The Atlantic is a digital-first media company with over 160 years of history and 36 million readers a month. Founded in 1857 and today one of the fastest-growing media platforms in the industry, The Atlantic has throughout its history championed the power of big ideas and continues to shape global debate through our two websites: TheAtlantic.com and CityLab.com. We work in a fast-paced, team-oriented environment out of our office in the historic Watergate complex in Washington DC. The role can be based in either Washington, DC or New York, NY.</p>\n<p><strong>Who You Are</strong></p>\n<p>You are an experienced developer and solid communicator with an interest in journalism and the media business.</p>\n<p>You’re well versed in the modern front-end: ES6, SCSS, understand what makes good markup, and how to best use the capabilities of the browser. You know how to collaborate with designers, are knowledgeable about CSS conventions and naming methodologies such as BEM, SMACSS, OOCSS, and can describe their relative merits. Your experience has taught you the architectural strategies and practices that are necessary for organizing and maintaining front end code that can scale as our team continues to grow.</p>\n<p>Above all, you’re a creative problem solver: able to devise and deliver practical, maintainable software that addresses Atlantic staffers’ and readers’ needs.</p>\n<p><strong>Primary Responsibilities:</strong></p>\n<ul>\n<li>Implement new features for TheAtlantic.com and CityLab.com where they will be viewed by millions of people</li>\n<li>Champion ways to improve our front end tech stack, including tooling, unit testing, and architecture</li>\n<li>Collaborate with team members to plan projects, creating technical road maps and breaking projects up into individual tasks as necessary</li>\n<li>Mentor junior developers and act as a subject expert</li>\n<li>Thinks strategically and systematically when planning or coding a project, always keeping in mind long term maintainability</li>\n<li>Work to continually reduce our front end website load time</li>\n<li>Communicate and collaborate with both technical and non-technical members of the team</li>\n</ul>\n<p><strong>Requirements:</strong>\n-Experience architecting a front end codebase at scale\n-Strong technical and non-technical communication skills\n-Able to write semantic and accessible markup that our growing team can easily maintain and iterate with\n-Able to look at a design and break it into well organized reusable components\n-Comfortable with Git for version control\n-Effective time management when working on multiple projects\n-Passionate about front end performance with up-to-date knowledge of current techniques\n-Familiar with Node.js\n-Knowledgeable about modern JavaScript frameworks but comfortable working in vanilla JS as appropriate\n-Able to provide a code sample demonstrating expertise at writing and organizing CSS, HTML, and JavaScript suitable for a complex, fast-changing website</p>\n<p><strong>Benefits</strong></p>\n<p>Employees at The Atlantic are entitled to benefits including: 401(k) savings plan with employer match, health care with domestic partner coverage, flexible vacation and sick leave policy, commuter benefits, and rooftop happy hours with one of the best views in DC.</p>\n<p><strong>Atlantic Media Values:</strong></p>\n<p>Across Atlantic Media, generally, the firm looks for two “pillar gifts” in you, and everyone else.  In all of us, these are more aspirational than actual, but they are central in our intentions –</p>\n<ul>\n<li>\n<strong>Force of Ideas</strong>: At the center of Atlantic Media work are the ideas within our writing. We believe that ideas – to the good and not – have consequence. Our highest work is bringing rigor, insight, intellectual integrity, to that ultimate purpose of separating the bad from the good, and giving voice to the latter.</li>\n<li>\n<strong>Spirit of Generosity</strong>: Atlantic Media seek ...
#   'how_to_apply': '<p>Apply online: <a href="https://atlanticmedia.theresumator.com/apply/EfTMcPw1rG/Senior-Front-End-Developer?source=Github">https://atlanticmedia.theresumator.com/apply/EfTMcPw1rG/Senior-Front-End-Developer?source=Github</a></p>\n',
#   'company_logo': 'https://jobs.github.com/rails/active_storage/blobs/eyJfcmFpbHMiOnsibWVzc2FnZSI6IkJBaHBBdEpXIiwiZXhwIjpudWxsLCJwdXIiOiJibG9iX2lkIn19--d395d665d7dd3f82d64d22e06b39f41ba13e36c9/f749e401-94c5-477e-8c8b-fb68335e240b'},
#  {'id': '76fcadae-e84e-11e8-88fc-96a168773892',
#   'type': 'Full Time',
#   'url': 'https://jobs.github.com/positions/76fcadae-e84e-11e8-88fc-96a168773892',
#   'created_at': 'Wed Nov 14 20:50:03 UTC 2018',
#   'company': 'NBCUniversal',
#   'company_url': 'https://www.nbcunicareers.com/',
#   'location': 'Universal City, CA',
#   'title': 'Media Software Engineer',
#   'description': '<p>Responsibilities :</p>\n<p>Coding at the component level and works under minimal supervision.\nAsset Management System Administration with systems, applications and service integrations.\nProvide proactive, regular, and professional-level communication with clients and team members alike\nManage system integration with 3rd party providers.\nProvide usage reports and track key metrics as required.\nEnsure delivered solutions enable the organization to manage the asset portfolio with respect to risk, cost, control, governance, compliance and business performance objectives\nCollaborate with stakeholders, developers, and system teams to design and maintain automation and deployment tools\nAssist project and technology teams in troubleshooting systems\nCreate dashboards and other tools for Project, Operations and Engineering teams to use in day-to-day monitoring and troubleshooting and enhance operational transparency within business units\nFollow Security Best Practices\nOccasional after hour support based on upgrades, new deployments and high-profile campaigns and/or market critical events.</p>\n<p>Job Requirements</p>\n<p>Knowledge/experience in relevant technologies, such as:\nXML Scripting\nJava/JavaScript\nJSON Messaging\nHTTP Protocol\nWeb Services (SOAP &amp; REST)\nPython, Ruby, Perl, and Smalltalk or other scripting languages preferred\nFamiliarity with ELK Stack (Prometheus) preferred\nAmazon Web Services technologies experience preferred\nAsset Management Systems\nSolid interpersonal skills with the ability to communicate and present to all levels of the organization and with external parties\nSelf-directed, highly motivated individual who can effectively manage multiple activities, pay attention to detail and a focus on continuous improvement.\nHigh degree of professionalism</p>\n<p>Desired Characteristics</p>\n<p>Scope of activities within projects include:\nBusiness requirements, documentation &amp; gap analysis\nCoordination of connectivity setup\nTechnical implementation/provisioning\nDevelop test plans, procedures and scripting for new workflows, integration and automated UI testing\nUnderstand Process flow and data mapping\nData preparation, deployment and analysis\nWeb services development\nApplication knowledge: Orchestration tools, Workflow Engines, Search Engines, BPM and transcoding.\nDatabase experience and network administration</p>\n',
#   'how_to_apply': '<p>If interested, please apply here: <a href="https://sjobs.brassring.com/TGWEbHost/jobdetails.aspx?partnerid=25354&amp;siteid=5108&amp;areq=43037BR">https://sjobs.brassring.com/TGWEbHost/jobdetails.aspx?partnerid=25354&amp;siteid=5108&amp;areq=43037BR</a></p>\n',
#   'company_logo': None}]

# %%
results = []

for i in range(5):
    r = requests.get(base_site , params = {'page': i+1})
    
    if len(r.json()):
        results.extend(r.json())
    else:
        break

# %%
len(results)
# Out:
# 191
